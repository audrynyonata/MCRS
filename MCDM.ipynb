# %% [markdown]
# ### DUMMY DATA

# %%
project_dict_string ='{"__v":0,"_id":{"$oid":"5d461b961e66c81988a999cc"},"characteristics":{"impact":{"_id":{"$oid":"5d461b961e66c81988a999ce"},"id":"approach","ref":"systemic/exploratory/explanatory","rule":"preference_list","value":["systemic","exploratory","explanatory"]},"expertise":{"_id":{"$oid":"5d461b961e66c81988a999d0"},"id":"expertise","ref":"default","rule":"minimum","value":[]},"formalism":{"_id":{"$oid":"5d461b961e66c81988a999cd"},"id":"formalism","ref":"formal/semi-formal/informal","rule":"preference_list","value":["formal","semi-formal","informal"]},"guidance":{"_id":{"$oid":"5d461b961e66c81988a999cf"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","rule":"preference_list","value":["predefined taxonomy","heuristics","guidelines"]},"impact":{"_id":{"$oid":"5d461b961e66c81988a999d2"},"id":"impact","ref":"default","rule":"maximum","value":[]},"level-of-innovation":{"_id":{"$oid":"5d461b961e66c81988a999d1"},"id":"level-of-innovation","ref":"default","rule":"maximum","value":[]}},"createdAt":{"$date":1564875671242},"description":"IS security chunks evaluation.","id":"company-a-ltd/test-project","name":"Test Project","project":"test-project","provider":"company-a-ltd","updatedAt":{"$date":1564875671242}}'

# %%
characteristics_dict_string = '{"approach":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28eb7"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28eb8"},"isQuantifiable":false,"ref":"systemic/exploratory/explanatory","values":["systemic","exploratory","explanatory"]}],"createdAt":{"$date":1564781410365},"id":"approach","name":"Approach","updatedAt":{"$date":1564781410365}},"expertise":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28ece"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28ed0"},"isQuantifiable":true,"ref":"default","values":["low","normal","high"]},{"_id":{"$oid":"5d44ab62ac770313a0f28ecf"},"isQuantifiable":false,"ref":"tester/developer/designer/analyst","values":["tester","developer","designer","analyst"]}],"createdAt":{"$date":1564781410366},"dimension":"human","id":"expertise","name":"Expertise","updatedAt":{"$date":1564781410366}},"formalism":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28eb9"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28eba"},"isQuantifiable":false,"ref":"formal/semi-formal/informal","values":["formal","semi-formal","informal"]}],"createdAt":{"$date":1564781410365},"id":"formalism","name":"Formalism","updatedAt":{"$date":1564781410365}},"guidance":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28eb5"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28eb6"},"isQuantifiable":false,"ref":"predefined taxonomy/heuristics/guidelines","values":["predefined taxonomy","heuristics","guidelines"]}],"createdAt":{"$date":1564781410364},"id":"guidance","name":"Guidance","updatedAt":{"$date":1564781410364}},"impact":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28ebf"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28ec0"},"isQuantifiable":true,"ref":"default","values":["low","normal","high"]}],"createdAt":{"$date":1564781410365},"dimension":"organisational","id":"impact","name":"Impact","updatedAt":{"$date":1564781410365}},"level-of-innovation":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28ec9"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28ecb"},"isQuantifiable":true,"ref":"default","values":["low","normal","high"]},{"_id":{"$oid":"5d44ab62ac770313a0f28eca"},"isQuantifiable":false,"ref":"business/technology","values":["business innovation","technology innovation"]}],"createdAt":{"$date":1564781410366},"dimension":"organisational","id":"level-of-innovation","name":"Level of innovation","updatedAt":{"$date":1564781410366}}}'

# %%
method_chunks_dict_string = '[{"__v":0,"_id":{"$oid":"5d46e54887e1f131781ea9d2"},"characteristics":{"approach":{"_id":{"$oid":"5d46e54887e1f131781ea9d4"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"explanatory"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781ea9d6"},"id":"expertise","ref":"default","value":"normal"},"formalism":{"_id":{"$oid":"5d46e54887e1f131781ea9d3"},"id":"formalism","ref":"formal/semi-formal/informal","value":"semi-formal"},"guidance":{"_id":{"$oid":"5d46e54887e1f131781ea9d5"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"predefined taxonomy"},"impact":{"_id":{"$oid":"5d46e54887e1f131781ea9d8"},"id":"impact","ref":"default","value":"high"},"level-of-innovation":{"_id":{"$oid":"5d46e54887e1f131781ea9d7"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564927304356},"description":"NFR Framework for IS Security","id":"nfr-framework","name":"NFR Framework","provider":"company-b","updatedAt":{"$date":1564927304356},"url":"http://example.com/NFR-framework"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781ea9d9"},"characteristics":{"approach":{"_id":{"$oid":"5d46e54887e1f131781ea9db"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"exploratory"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781ea9dd"},"id":"expertise","ref":"default","value":"high"},"formalism":{"_id":{"$oid":"5d46e54887e1f131781ea9da"},"id":"formalism","ref":"formal/semi-formal/informal","value":"formal"},"guidance":{"_id":{"$oid":"5d46e54887e1f131781ea9dc"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"heuristics"},"impact":{"_id":{"$oid":"5d46e54887e1f131781ea9df"},"id":"impact","ref":"default","value":"low"},"level-of-innovation":{"_id":{"$oid":"5d46e54887e1f131781ea9de"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564927304357},"description":"KAOS for IS Security","id":"kaos","name":"KAOS","provider":"company-a","updatedAt":{"$date":1564927304357},"url":"http://example.com/KAOS"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781ea9e0"},"characteristics":{"approach":{"_id":{"$oid":"5d46e54887e1f131781ea9e2"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"systemic"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781ea9e3"},"id":"expertise","ref":"default","value":"high"},"formalism":{"_id":{"$oid":"5d46e54887e1f131781ea9e1"},"id":"formalism","ref":"formal/semi-formal/informal","value":"formal"},"impact":{"_id":{"$oid":"5d46e54887e1f131781ea9e5"},"id":"impact","ref":"default","value":"high"},"level-of-innovation":{"_id":{"$oid":"5d46e54887e1f131781ea9e4"},"id":"level-of-innovation","ref":"default","value":"low"}},"createdAt":{"$date":1564927304358},"description":"Secure Tropos for IS Security","id":"secure-tropos","name":"Secure Tropos","provider":"company-a","updatedAt":{"$date":1564927304358},"url":"http://example.com/secure-tropos"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781ea9e6"},"characteristics":{"expertise":{"_id":{"$oid":"5d46e54887e1f131781ea9e9"},"id":"expertise","ref":"default","value":"normal"},"formalism":{"_id":{"$oid":"5d46e54887e1f131781ea9e7"},"id":"formalism","ref":"formal/semi-formal/informal","value":"informal"},"guidance":{"_id":{"$oid":"5d46e54887e1f131781ea9e8"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"heuristics"},"impact":{"_id":{"$oid":"5d46e54887e1f131781ea9eb"},"id":"impact","ref":"default","value":"low"},"level-of-innovation":{"_id":{"$oid":"5d46e54887e1f131781ea9ea"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564927304358},"description":"GBRAM for IS Security","id":"gbram","name":"GBRAM","provider":"company-b","updatedAt":{"$date":1564927304358},"url":"http://example.com/gbram"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781ea9ec"},"characteristics":{"approach":{"_id":{"$oid":"5d46e54887e1f131781ea9ee"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"explanatory"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781ea9f0"},"id":"expertise","ref":"default","value":"low"},"formalism":{"_id":{"$oid":"5d46e54887e1f131781ea9ed"},"id":"formalism","ref":"formal/semi-formal/informal","value":"informal"},"guidance":{"_id":{"$oid":"5d46e54887e1f131781ea9ef"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"guidelines"},"impact":{"_id":{"$oid":"5d46e54887e1f131781ea9f2"},"id":"impact","ref":"default","value":"normal"},"level-of-innovation":{"_id":{"$oid":"5d46e54887e1f131781ea9f1"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564927304359},"description":"Misuse Cases for IS Security","id":"misuse-cases","name":"Misuse Cases","provider":"company-a","updatedAt":{"$date":1564927304359},"url":"http://example.com/misusecases"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781ea9f3"},"characteristics":{"expertise":{"_id":{"$oid":"5d46e54887e1f131781ea9f6"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d46e54887e1f131781ea9f4"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d46e54887e1f131781ea9f7"},"id":"importance","ref":"default","value":"normal"},"management-commitment":{"_id":{"$oid":"5d46e54887e1f131781ea9f8"},"id":"management-commitment","ref":"default","value":"low"},"user-involvement":{"_id":{"$oid":"5d46e54887e1f131781ea9f5"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564927304360},"description":"Acceptance test–driven development (ATDD) is a development methodology based on communication between the business customers, the developers, and the testers. ATDD encompasses many of the same practices as specification by example (SBE),[2][3] behavior-driven development (BDD),[4] example-driven development (EDD), and support-driven development also called story test–driven development (SDD). All these processes aid developers and testers in understanding the customer\'s needs prior to implementation and allow customers to be able to converse in their own domain language. ATDD is closely related to test-driven development (TDD). It differs by the emphasis on developer-tester-business customer collaboration. ATDD encompasses acceptance testing, but highlights writing acceptance tests before developers begin coding.","id":"acceptance-test-driven-development","name":"Acceptance Test Driven Development","provider":"company-a","updatedAt":{"$date":1564927304360},"url":"http://example.com/AcceptanceTestDrivenDevelopment"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781ea9ff"},"characteristics":{"formality":{"_id":{"$oid":"5d46e54887e1f131781eaa02"},"id":"formality","ref":"default","value":"low"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa04"},"id":"impact","ref":"default","value":"high"},"resistance-and-conflict":{"_id":{"$oid":"5d46e54887e1f131781eaa03"},"id":"resistance-and-conflict","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d46e54887e1f131781eaa00"},"id":"tracing-project","ref":"default","value":"strong"},"variability":{"_id":{"$oid":"5d46e54887e1f131781eaa01"},"id":"variability","ref":"default","value":"high"}},"createdAt":{"$date":1564927304362},"description":"Make incremental improvements to the way of working through regular, repeated retrospectives.","id":"agile-retrospective","name":"Agile Retrospective","provider":"company-a","updatedAt":{"$date":1564927304362},"url":"http://example.com/AgileRetrospective"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa05"},"characteristics":{"expertise":{"_id":{"$oid":"5d46e54887e1f131781eaa08"},"id":"expertise","ref":"default","value":"high"},"formality":{"_id":{"$oid":"5d46e54887e1f131781eaa06"},"id":"formality","ref":"default","value":"low"},"management-commitment":{"_id":{"$oid":"5d46e54887e1f131781eaa09"},"id":"management-commitment","ref":"default","value":"normal"},"resistance-and-conflict":{"_id":{"$oid":"5d46e54887e1f131781eaa07"},"id":"resistance-and-conflict","ref":"default","value":"high"}},"createdAt":{"$date":1564927304362},"description":"A self-organizing team maximizes its performance by using a highly-collaborative teaming approach.","id":"agile-teaming","name":"Agile Teaming","provider":"company-a","updatedAt":{"$date":1564927304362},"url":"http://example.com/AgileTeaming"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa11"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d46e54887e1f131781eaa14"},"id":"clarity-and-stability","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa12"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d46e54887e1f131781eaa15"},"id":"importance","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d46e54887e1f131781eaa16"},"id":"management-commitment","ref":"default","value":"high"},"user-involvement":{"_id":{"$oid":"5d46e54887e1f131781eaa13"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564927304363},"description":"In software engineering, behavior-driven development (BDD) is an Agile software development process that encourages collaboration between developers, QA and non-technical or business participants in a software project. It encourages teams to use conversation and concrete examples to formalize a shared understanding of how the application should behave. Although BDD is principally an idea about how software development should be managed by both business interests and technical insight, the practice of BDD does assume the use of specialized software tools to support the development process. BDD is largely facilitated through the use of a simple domain-specific language (DSL) using natural language constructs (e.g., English-like sentences) that can express the behavior and the expected outcomes. BDD helps to focus on the user’s needs and the system’s expected behavior rather than focusing too much on testing the implementation.","id":"behavior-driven-development","name":"Behavior Driven Development","provider":"company-a","updatedAt":{"$date":1564927304363},"url":"http://example.com/BehaviorDrivenDevelopment"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa17"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d46e54887e1f131781eaa1a"},"id":"clarity-and-stability","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa18"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d46e54887e1f131781eaa1b"},"id":"importance","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d46e54887e1f131781eaa1c"},"id":"management-commitment","ref":"default","value":"high"},"user-involvement":{"_id":{"$oid":"5d46e54887e1f131781eaa19"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564927304364},"description":"Big Design Up Front (BDUF) is a software development approach in which the program\'s design is to be completed and perfected before that program\'s implementation is started. It is often associated with the waterfall model of software development. Proponents of waterfall model argue that time spent in designing is a worthwhile investment, with the hope that less time and effort will be spent fixing a bug in the early stages of a software product\'s lifecycle than when that same bug is found and must be fixed later. That is, it is much easier to fix a requirements bug in the requirements phase than to fix that same bug in the implementation phase, as to fix a requirements bug in the implementation phase requires scrapping at least some of the implementation and design work which has already been completed.","id":"big-design-up-front","name":"Big Design Up Front","provider":"company-a","updatedAt":{"$date":1564927304364},"url":"http://example.com/BigDesignUpFront"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa1d"},"characteristics":{"complexity":{"_id":{"$oid":"5d46e54887e1f131781eaa1f"},"id":"complexity","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781eaa21"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa1e"},"id":"impact","ref":"default","value":"high"},"time-pressure":{"_id":{"$oid":"5d46e54887e1f131781eaa22"},"id":"time-pressure","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d46e54887e1f131781eaa20"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564927304365},"description":"Continuous delivery (CD or CDE) is a software engineering approach in which teams produce software in short cycles, ensuring that the software can be reliably released at any time and, when releasing the software, doing so manually. It aims at building, testing, and releasing software with greater speed and frequency. The approach helps reduce the cost, time, and risk of delivering changes by allowing for more incremental updates to applications in production. A straightforward and repeatable deployment process is important for continuous delivery.","id":"continuous-delivery","name":"Continuous Delivery","provider":"company-a","updatedAt":{"$date":1564927304365},"url":"http://example.com/ContinuousDelivery"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa23"},"characteristics":{"complexity":{"_id":{"$oid":"5d46e54887e1f131781eaa25"},"id":"complexity","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781eaa27"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa24"},"id":"impact","ref":"default","value":"high"},"time-pressure":{"_id":{"$oid":"5d46e54887e1f131781eaa28"},"id":"time-pressure","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d46e54887e1f131781eaa26"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564927304365},"description":"Continuous integration (CI) is the practice of merging all developer working copies to a shared mainline several times a day. Continuous integration involves integrating early and often, so as to avoid the pitfalls of \'integration hell\'.","id":"continuous-integration","name":"Continuous Integration","provider":"company-a","updatedAt":{"$date":1564927304365},"url":"http://example.com/ContinuousIntegration"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa29"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d46e54887e1f131781eaa2d"},"id":"clarity-and-stability","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781eaa2c"},"id":"expertise","ref":"default","value":"low"},"formality":{"_id":{"$oid":"5d46e54887e1f131781eaa2b"},"id":"formality","ref":"default","value":"low"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa2e"},"id":"impact","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d46e54887e1f131781eaa30"},"id":"management-commitment","ref":"default","value":"high"},"time-pressure":{"_id":{"$oid":"5d46e54887e1f131781eaa2f"},"id":"time-pressure","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d46e54887e1f131781eaa2a"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564927304365},"description":"Use short, daily whole-team meetings to coordinate the work of the team and raise impediments.","id":"daily-stand-up","name":"Daily Stand-Up","provider":"company-a","updatedAt":{"$date":1564927304365},"url":"http://example.com/DailyStandUp"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa31"},"characteristics":{"complexity":{"_id":{"$oid":"5d46e54887e1f131781eaa33"},"id":"complexity","ref":"default","value":"normal"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781eaa35"},"id":"expertise","ref":"default","value":"low"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa32"},"id":"impact","ref":"default","value":"high"},"resistance-and-conflict":{"_id":{"$oid":"5d46e54887e1f131781eaa36"},"id":"resistance-and-conflict","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d46e54887e1f131781eaa34"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564927304365},"description":"Agile software development technique in which two programmers work together at one workstation. One, the driver, writes code while the other, the observer or navigator,reviews each line of code as it is typed in. The two programmers switch roles frequently. While reviewing, the observer also considers the strategic direction of the work, coming up with ideas for improvements and likely future problems to address. This is intended to free the driver to focus all of their attention on the tactical aspects of completing the current task, using the observer as a safety net and guide. Pair programming increases the man-hours required to deliver code compared to programmers working individually. Experiments yielded diverse results, suggesting increases of between 15% and 100%. However, the resulting code has about 15% fewer defects. Along with code development time, other factors like field support costs and quality assurance also figure in to the return on investment.","id":"pair-programming","name":"Pair Programming","provider":"company-a","updatedAt":{"$date":1564927304366},"url":"http://example.com/PairProgramming"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa3d"},"characteristics":{"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa3f"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d46e54887e1f131781eaa40"},"id":"importance","ref":"default","value":"normal"},"management-commitment":{"_id":{"$oid":"5d46e54887e1f131781eaa41"},"id":"management-commitment","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d46e54887e1f131781eaa3e"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564927304366},"description":"Own, evolve and communicate the vision, and guide the evolution of the product to achieve the vision.","id":"product-ownership","name":"Product Ownership","provider":"company-a","updatedAt":{"$date":1564927304366},"url":"http://example.com/ProductOwnership"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa42"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d46e54887e1f131781eaa45"},"id":"clarity-and-stability","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa43"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d46e54887e1f131781eaa46"},"id":"importance","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d46e54887e1f131781eaa47"},"id":"management-commitment","ref":"default","value":"high"},"user-involvement":{"_id":{"$oid":"5d46e54887e1f131781eaa44"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564927304366},"description":"Specification by example (SBE) is a collaborative approach to defining requirements and business-oriented functional tests for software products based on capturing and illustrating requirements using realistic examples instead of abstract statements. It is applied in the context of agile software development methods, in particular behavior-driven development. This approach is particularly successful for managing requirements and functional tests on large-scale projects of significant domain and organisational complexity.","id":"specification-by-example","name":"Specification By Example","provider":"company-a","updatedAt":{"$date":1564927304366},"url":"http://example.com/SpecificationByExample"},{"__v":0,"_id":{"$oid":"5d46e54887e1f131781eaa48"},"characteristics":{"complexity":{"_id":{"$oid":"5d46e54887e1f131781eaa4a"},"id":"complexity","ref":"default","value":"high"},"dependency":{"_id":{"$oid":"5d46e54887e1f131781eaa4d"},"id":"dependency","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d46e54887e1f131781eaa4c"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d46e54887e1f131781eaa49"},"id":"impact","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d46e54887e1f131781eaa4b"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564927304366},"description":"Test-driven development (TDD) is a software development process that relies on the repetition of a very short development cycle: requirements are turned into very specific test cases, then the software is improved to pass the new tests, only. This is opposed to software development that allows software to be added that is not proven to meet requirements. Writing the tests first: The tests should be written before the functionality that is to be tested. This has been claimed to have many benefits. It helps ensure that the application is written for testability, as the developers must consider how to test the application from the outset rather than adding it later. It also ensures that tests for every feature get written. Additionally, writing the tests first leads to a deeper and earlier understanding of the product requirements, ensures the effectiveness of the test code, and maintains a continual focus on software quality.","id":"test-driven-development","name":"Test Driven Development","provider":"company-a","updatedAt":{"$date":1564927304366},"url":"http://example.com/TestDrivenDevelopment"}]'

# %%
import json
project = json.loads(project_dict_string)
method_chunks = json.loads(method_chunks_dict_string)
characteristics = json.loads(characteristics_dict_string)

# %%
print(json.dumps(project, indent=4))
# Out:
# {
#     "__v": 0,
#     "_id": {
#         "$oid": "5d461b961e66c81988a999cc"
#     },
#     "characteristics": {
#         "impact": {
#             "_id": {
#                 "$oid": "5d461b961e66c81988a999d2"
#             },
#             "id": "impact",
#             "ref": "default",
#             "rule": "maximum",
#             "value": []
#         },
#         "expertise": {
#             "_id": {
#                 "$oid": "5d461b961e66c81988a999d0"
#             },
#             "id": "expertise",
#             "ref": "default",
#             "rule": "minimum",
#             "value": []
#         },
#         "formalism": {
#             "_id": {
#                 "$oid": "5d461b961e66c81988a999cd"
#             },
#             "id": "formalism",
#             "ref": "formal/semi-formal/informal",
#             "rule": "preference_list",
#             "value": [
#                 "formal",
#                 "semi-formal",
#                 "informal"
#             ]
#         },
#         "guidance": {
#             "_id": {
#                 "$oid": "5d461b961e66c81988a999cf"
#             },
#             "id": "guidance",
#             "ref": "predefined taxonomy/heuristics/guidelines",
#             "rule": "preference_list",
#             "value": [
#                 "predefined taxonomy",
#                 "heuristics",
#                 "guidelines"
#             ]
#         },
#         "level-of-innovation": {
#             "_id": {
#                 "$oid": "5d461b961e66c81988a999d1"
#             },
#             "id": "level-of-innovation",
#             "ref": "default",
#             "rule": "maximum",
#             "value": []
#         }
#     },
#     "createdAt": {
#         "$date": 1564875671242
#     },
#     "description": "IS security chunks evaluation.",
#     "id": "company-a-ltd/test-project",
#     "name": "Test Project",
#     "project": "test-project",
#     "provider": "company-a-ltd",
#     "updatedAt": {
#         "$date": 1564875671242
#     }
# }

# %%
print(json.dumps(method_chunks, indent=4))
# Out:
# [
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781ea9d2"
#         },
#         "characteristics": {
#             "approach": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9d4"
#                 },
#                 "id": "approach",
#                 "ref": "systemic/exploratory/explanatory",
#                 "value": "explanatory"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9d6"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "normal"
#             },
#             "formalism": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9d3"
#                 },
#                 "id": "formalism",
#                 "ref": "formal/semi-formal/informal",
#                 "value": "semi-formal"
#             },
#             "guidance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9d5"
#                 },
#                 "id": "guidance",
#                 "ref": "predefined taxonomy/heuristics/guidelines",
#                 "value": "predefined taxonomy"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9d8"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "level-of-innovation": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9d7"
#                 },
#                 "id": "level-of-innovation",
#                 "ref": "default",
#                 "value": "high"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304356
#         },
#         "description": "NFR Framework for IS Security",
#         "id": "nfr-framework",
#         "name": "NFR Framework",
#         "provider": "company-b",
#         "updatedAt": {
#             "$date": 1564927304356
#         },
#         "url": "http://example.com/NFR-framework"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781ea9d9"
#         },
#         "characteristics": {
#             "approach": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9db"
#                 },
#                 "id": "approach",
#                 "ref": "systemic/exploratory/explanatory",
#                 "value": "exploratory"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9dd"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "formalism": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9da"
#                 },
#                 "id": "formalism",
#                 "ref": "formal/semi-formal/informal",
#                 "value": "formal"
#             },
#             "guidance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9dc"
#                 },
#                 "id": "guidance",
#                 "ref": "predefined taxonomy/heuristics/guidelines",
#                 "value": "heuristics"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9df"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "level-of-innovation": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9de"
#                 },
#                 "id": "level-of-innovation",
#                 "ref": "default",
#                 "value": "high"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304357
#         },
#         "description": "KAOS for IS Security",
#         "id": "kaos",
#         "name": "KAOS",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304357
#         },
#         "url": "http://example.com/KAOS"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781ea9e0"
#         },
#         "characteristics": {
#             "approach": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e2"
#                 },
#                 "id": "approach",
#                 "ref": "systemic/exploratory/explanatory",
#                 "value": "systemic"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e3"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "formalism": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e1"
#                 },
#                 "id": "formalism",
#                 "ref": "formal/semi-formal/informal",
#                 "value": "formal"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e5"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "level-of-innovation": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e4"
#                 },
#                 "id": "level-of-innovation",
#                 "ref": "default",
#                 "value": "low"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304358
#         },
#         "description": "Secure Tropos for IS Security",
#         "id": "secure-tropos",
#         "name": "Secure Tropos",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304358
#         },
#         "url": "http://example.com/secure-tropos"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781ea9e6"
#         },
#         "characteristics": {
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e9"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "normal"
#             },
#             "formalism": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e7"
#                 },
#                 "id": "formalism",
#                 "ref": "formal/semi-formal/informal",
#                 "value": "informal"
#             },
#             "guidance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9e8"
#                 },
#                 "id": "guidance",
#                 "ref": "predefined taxonomy/heuristics/guidelines",
#                 "value": "heuristics"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9eb"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "level-of-innovation": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9ea"
#                 },
#                 "id": "level-of-innovation",
#                 "ref": "default",
#                 "value": "high"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304358
#         },
#         "description": "GBRAM for IS Security",
#         "id": "gbram",
#         "name": "GBRAM",
#         "provider": "company-b",
#         "updatedAt": {
#             "$date": 1564927304358
#         },
#         "url": "http://example.com/gbram"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781ea9ec"
#         },
#         "characteristics": {
#             "approach": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9ee"
#                 },
#                 "id": "approach",
#                 "ref": "systemic/exploratory/explanatory",
#                 "value": "explanatory"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f0"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "formalism": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9ed"
#                 },
#                 "id": "formalism",
#                 "ref": "formal/semi-formal/informal",
#                 "value": "informal"
#             },
#             "guidance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9ef"
#                 },
#                 "id": "guidance",
#                 "ref": "predefined taxonomy/heuristics/guidelines",
#                 "value": "guidelines"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f2"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "normal"
#             },
#             "level-of-innovation": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f1"
#                 },
#                 "id": "level-of-innovation",
#                 "ref": "default",
#                 "value": "high"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304359
#         },
#         "description": "Misuse Cases for IS Security",
#         "id": "misuse-cases",
#         "name": "Misuse Cases",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304359
#         },
#         "url": "http://example.com/misusecases"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781ea9f3"
#         },
#         "characteristics": {
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f6"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f4"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "importance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f7"
#                 },
#                 "id": "importance",
#                 "ref": "default",
#                 "value": "normal"
#             },
#             "management-commitment": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f8"
#                 },
#                 "id": "management-commitment",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "user-involvement": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781ea9f5"
#                 },
#                 "id": "user-involvement",
#                 "ref": "default",
#                 "value": "real"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304360
#         },
#         "description": "Acceptance test\u2013driven development (ATDD) is a development methodology based on communication between the business customers, the developers, and the testers. ATDD encompasses many of the same practices as specification by example (SBE),[2][3] behavior-driven development (BDD),[4] example-driven development (EDD), and support-driven development also called story test\u2013driven development (SDD). All these processes aid developers and testers in understanding the customer's needs prior to implementation and allow customers to be able to converse in their own domain language. ATDD is closely related to test-driven development (TDD). It differs by the emphasis on developer-tester-business customer collaboration. ATDD encompasses acceptance testing, but highlights writing acceptance tests before developers begin coding.",
#         "id": "acceptance-test-driven-development",
#         "name": "Acceptance Test Driven Development",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304360
#         },
#         "url": "http://example.com/AcceptanceTestDrivenDevelopment"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781ea9ff"
#         },
#         "characteristics": {
#             "formality": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa02"
#                 },
#                 "id": "formality",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa04"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "resistance-and-conflict": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa03"
#                 },
#                 "id": "resistance-and-conflict",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "tracing-project": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa00"
#                 },
#                 "id": "tracing-project",
#                 "ref": "default",
#                 "value": "strong"
#             },
#             "variability": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa01"
#                 },
#                 "id": "variability",
#                 "ref": "default",
#                 "value": "high"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304362
#         },
#         "description": "Make incremental improvements to the way of working through regular, repeated retrospectives.",
#         "id": "agile-retrospective",
#         "name": "Agile Retrospective",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304362
#         },
#         "url": "http://example.com/AgileRetrospective"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa05"
#         },
#         "characteristics": {
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa08"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "formality": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa06"
#                 },
#                 "id": "formality",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "management-commitment": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa09"
#                 },
#                 "id": "management-commitment",
#                 "ref": "default",
#                 "value": "normal"
#             },
#             "resistance-and-conflict": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa07"
#                 },
#                 "id": "resistance-and-conflict",
#                 "ref": "default",
#                 "value": "high"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304362
#         },
#         "description": "A self-organizing team maximizes its performance by using a highly-collaborative teaming approach.",
#         "id": "agile-teaming",
#         "name": "Agile Teaming",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304362
#         },
#         "url": "http://example.com/AgileTeaming"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa11"
#         },
#         "characteristics": {
#             "clarity-and-stability": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa14"
#                 },
#                 "id": "clarity-and-stability",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa12"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "importance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa15"
#                 },
#                 "id": "importance",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "management-commitment": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa16"
#                 },
#                 "id": "management-commitment",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "user-involvement": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa13"
#                 },
#                 "id": "user-involvement",
#                 "ref": "default",
#                 "value": "real"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304363
#         },
#         "description": "In software engineering, behavior-driven development (BDD) is an Agile software development process that encourages collaboration between developers, QA and non-technical or business participants in a software project. It encourages teams to use conversation and concrete examples to formalize a shared understanding of how the application should behave. Although BDD is principally an idea about how software development should be managed by both business interests and technical insight, the practice of BDD does assume the use of specialized software tools to support the development process. BDD is largely facilitated through the use of a simple domain-specific language (DSL) using natural language constructs (e.g., English-like sentences) that can express the behavior and the expected outcomes. BDD helps to focus on the user\u2019s needs and the system\u2019s expected behavior rather than focusing too much on testing the implementation.",
#         "id": "behavior-driven-development",
#         "name": "Behavior Driven Development",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304363
#         },
#         "url": "http://example.com/BehaviorDrivenDevelopment"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa17"
#         },
#         "characteristics": {
#             "clarity-and-stability": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa1a"
#                 },
#                 "id": "clarity-and-stability",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa18"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "importance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa1b"
#                 },
#                 "id": "importance",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "management-commitment": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa1c"
#                 },
#                 "id": "management-commitment",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "user-involvement": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa19"
#                 },
#                 "id": "user-involvement",
#                 "ref": "default",
#                 "value": "real"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304364
#         },
#         "description": "Big Design Up Front (BDUF) is a software development approach in which the program's design is to be completed and perfected before that program's implementation is started. It is often associated with the waterfall model of software development. Proponents of waterfall model argue that time spent in designing is a worthwhile investment, with the hope that less time and effort will be spent fixing a bug in the early stages of a software product's lifecycle than when that same bug is found and must be fixed later. That is, it is much easier to fix a requirements bug in the requirements phase than to fix that same bug in the implementation phase, as to fix a requirements bug in the implementation phase requires scrapping at least some of the implementation and design work which has already been completed.",
#         "id": "big-design-up-front",
#         "name": "Big Design Up Front",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304364
#         },
#         "url": "http://example.com/BigDesignUpFront"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa1d"
#         },
#         "characteristics": {
#             "complexity": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa1f"
#                 },
#                 "id": "complexity",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa21"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa1e"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "time-pressure": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa22"
#                 },
#                 "id": "time-pressure",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "tracing-project": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa20"
#                 },
#                 "id": "tracing-project",
#                 "ref": "default",
#                 "value": "strong"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304365
#         },
#         "description": "Continuous delivery (CD or CDE) is a software engineering approach in which teams produce software in short cycles, ensuring that the software can be reliably released at any time and, when releasing the software, doing so manually. It aims at building, testing, and releasing software with greater speed and frequency. The approach helps reduce the cost, time, and risk of delivering changes by allowing for more incremental updates to applications in production. A straightforward and repeatable deployment process is important for continuous delivery.",
#         "id": "continuous-delivery",
#         "name": "Continuous Delivery",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304365
#         },
#         "url": "http://example.com/ContinuousDelivery"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa23"
#         },
#         "characteristics": {
#             "complexity": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa25"
#                 },
#                 "id": "complexity",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa27"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa24"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "time-pressure": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa28"
#                 },
#                 "id": "time-pressure",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "tracing-project": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa26"
#                 },
#                 "id": "tracing-project",
#                 "ref": "default",
#                 "value": "strong"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304365
#         },
#         "description": "Continuous integration (CI) is the practice of merging all developer working copies to a shared mainline several times a day. Continuous integration involves integrating early and often, so as to avoid the pitfalls of 'integration hell'.",
#         "id": "continuous-integration",
#         "name": "Continuous Integration",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304365
#         },
#         "url": "http://example.com/ContinuousIntegration"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa29"
#         },
#         "characteristics": {
#             "clarity-and-stability": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa2d"
#                 },
#                 "id": "clarity-and-stability",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa2c"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "formality": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa2b"
#                 },
#                 "id": "formality",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa2e"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "management-commitment": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa30"
#                 },
#                 "id": "management-commitment",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "time-pressure": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa2f"
#                 },
#                 "id": "time-pressure",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "tracing-project": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa2a"
#                 },
#                 "id": "tracing-project",
#                 "ref": "default",
#                 "value": "strong"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304365
#         },
#         "description": "Use short, daily whole-team meetings to coordinate the work of the team and raise impediments.",
#         "id": "daily-stand-up",
#         "name": "Daily Stand-Up",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304365
#         },
#         "url": "http://example.com/DailyStandUp"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa31"
#         },
#         "characteristics": {
#             "complexity": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa33"
#                 },
#                 "id": "complexity",
#                 "ref": "default",
#                 "value": "normal"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa35"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "low"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa32"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "resistance-and-conflict": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa36"
#                 },
#                 "id": "resistance-and-conflict",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "tracing-project": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa34"
#                 },
#                 "id": "tracing-project",
#                 "ref": "default",
#                 "value": "strong"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304365
#         },
#         "description": "Agile software development technique in which two programmers work together at one workstation. One, the driver, writes code while the other, the observer or navigator,reviews each line of code as it is typed in. The two programmers switch roles frequently. While reviewing, the observer also considers the strategic direction of the work, coming up with ideas for improvements and likely future problems to address. This is intended to free the driver to focus all of their attention on the tactical aspects of completing the current task, using the observer as a safety net and guide. Pair programming increases the man-hours required to deliver code compared to programmers working individually. Experiments yielded diverse results, suggesting increases of between 15% and 100%. However, the resulting code has about 15% fewer defects. Along with code development time, other factors like field support costs and quality assurance also figure in to the return on investment.",
#         "id": "pair-programming",
#         "name": "Pair Programming",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304366
#         },
#         "url": "http://example.com/PairProgramming"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa3d"
#         },
#         "characteristics": {
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa3f"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "importance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa40"
#                 },
#                 "id": "importance",
#                 "ref": "default",
#                 "value": "normal"
#             },
#             "management-commitment": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa41"
#                 },
#                 "id": "management-commitment",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "tracing-project": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa3e"
#                 },
#                 "id": "tracing-project",
#                 "ref": "default",
#                 "value": "strong"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304366
#         },
#         "description": "Own, evolve and communicate the vision, and guide the evolution of the product to achieve the vision.",
#         "id": "product-ownership",
#         "name": "Product Ownership",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304366
#         },
#         "url": "http://example.com/ProductOwnership"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa42"
#         },
#         "characteristics": {
#             "clarity-and-stability": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa45"
#                 },
#                 "id": "clarity-and-stability",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa43"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "importance": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa46"
#                 },
#                 "id": "importance",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "management-commitment": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa47"
#                 },
#                 "id": "management-commitment",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "user-involvement": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa44"
#                 },
#                 "id": "user-involvement",
#                 "ref": "default",
#                 "value": "real"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304366
#         },
#         "description": "Specification by example (SBE) is a collaborative approach to defining requirements and business-oriented functional tests for software products based on capturing and illustrating requirements using realistic examples instead of abstract statements. It is applied in the context of agile software development methods, in particular behavior-driven development. This approach is particularly successful for managing requirements and functional tests on large-scale projects of significant domain and organisational complexity.",
#         "id": "specification-by-example",
#         "name": "Specification By Example",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304366
#         },
#         "url": "http://example.com/SpecificationByExample"
#     },
#     {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d46e54887e1f131781eaa48"
#         },
#         "characteristics": {
#             "complexity": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa4a"
#                 },
#                 "id": "complexity",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "dependency": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa4d"
#                 },
#                 "id": "dependency",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "expertise": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa4c"
#                 },
#                 "id": "expertise",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "impact": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa49"
#                 },
#                 "id": "impact",
#                 "ref": "default",
#                 "value": "high"
#             },
#             "tracing-project": {
#                 "_id": {
#                     "$oid": "5d46e54887e1f131781eaa4b"
#                 },
#                 "id": "tracing-project",
#                 "ref": "default",
#                 "value": "strong"
#             }
#         },
#         "createdAt": {
#             "$date": 1564927304366
#         },
#         "description": "Test-driven development (TDD) is a software development process that relies on the repetition of a very short development cycle: requirements are turned into very specific test cases, then the software is improved to pass the new tests, only. This is opposed to software development that allows software to be added that is not proven to meet requirements. Writing the tests first: The tests should be written before the functionality that is to be tested. This has been claimed to have many benefits. It helps ensure that the application is written for testability, as the developers must consider how to test the application from the outset rather than adding it later. It also ensures that tests for every feature get written. Additionally, writing the tests first leads to a deeper and earlier understanding of the product requirements, ensures the effectiveness of the test code, and maintains a continual focus on software quality.",
#         "id": "test-driven-development",
#         "name": "Test Driven Development",
#         "provider": "company-a",
#         "updatedAt": {
#             "$date": 1564927304366
#         },
#         "url": "http://example.com/TestDrivenDevelopment"
#     }
# ]

# %%
print(json.dumps(characteristics, indent=4))
# Out:
# {
#     "approach": {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d44ab62ac770313a0f28eb7"
#         },
#         "characteristicValues": [
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28eb8"
#                 },
#                 "isQuantifiable": false,
#                 "ref": "systemic/exploratory/explanatory",
#                 "values": [
#                     "systemic",
#                     "exploratory",
#                     "explanatory"
#                 ]
#             }
#         ],
#         "createdAt": {
#             "$date": 1564781410365
#         },
#         "id": "approach",
#         "name": "Approach",
#         "updatedAt": {
#             "$date": 1564781410365
#         }
#     },
#     "expertise": {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d44ab62ac770313a0f28ece"
#         },
#         "characteristicValues": [
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28ed0"
#                 },
#                 "isQuantifiable": true,
#                 "ref": "default",
#                 "values": [
#                     "low",
#                     "normal",
#                     "high"
#                 ]
#             },
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28ecf"
#                 },
#                 "isQuantifiable": false,
#                 "ref": "tester/developer/designer/analyst",
#                 "values": [
#                     "tester",
#                     "developer",
#                     "designer",
#                     "analyst"
#                 ]
#             }
#         ],
#         "createdAt": {
#             "$date": 1564781410366
#         },
#         "dimension": "human",
#         "id": "expertise",
#         "name": "Expertise",
#         "updatedAt": {
#             "$date": 1564781410366
#         }
#     },
#     "formalism": {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d44ab62ac770313a0f28eb9"
#         },
#         "characteristicValues": [
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28eba"
#                 },
#                 "isQuantifiable": false,
#                 "ref": "formal/semi-formal/informal",
#                 "values": [
#                     "formal",
#                     "semi-formal",
#                     "informal"
#                 ]
#             }
#         ],
#         "createdAt": {
#             "$date": 1564781410365
#         },
#         "id": "formalism",
#         "name": "Formalism",
#         "updatedAt": {
#             "$date": 1564781410365
#         }
#     },
#     "guidance": {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d44ab62ac770313a0f28eb5"
#         },
#         "characteristicValues": [
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28eb6"
#                 },
#                 "isQuantifiable": false,
#                 "ref": "predefined taxonomy/heuristics/guidelines",
#                 "values": [
#                     "predefined taxonomy",
#                     "heuristics",
#                     "guidelines"
#                 ]
#             }
#         ],
#         "createdAt": {
#             "$date": 1564781410364
#         },
#         "id": "guidance",
#         "name": "Guidance",
#         "updatedAt": {
#             "$date": 1564781410364
#         }
#     },
#     "impact": {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d44ab62ac770313a0f28ebf"
#         },
#         "characteristicValues": [
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28ec0"
#                 },
#                 "isQuantifiable": true,
#                 "ref": "default",
#                 "values": [
#                     "low",
#                     "normal",
#                     "high"
#                 ]
#             }
#         ],
#         "createdAt": {
#             "$date": 1564781410365
#         },
#         "dimension": "organisational",
#         "id": "impact",
#         "name": "Impact",
#         "updatedAt": {
#             "$date": 1564781410365
#         }
#     },
#     "level-of-innovation": {
#         "__v": 0,
#         "_id": {
#             "$oid": "5d44ab62ac770313a0f28ec9"
#         },
#         "characteristicValues": [
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28ecb"
#                 },
#                 "isQuantifiable": true,
#                 "ref": "default",
#                 "values": [
#                     "low",
#                     "normal",
#                     "high"
#                 ]
#             },
#             {
#                 "_id": {
#                     "$oid": "5d44ab62ac770313a0f28eca"
#                 },
#                 "isQuantifiable": false,
#                 "ref": "business/technology",
#                 "values": [
#                     "business innovation",
#                     "technology innovation"
#                 ]
#             }
#         ],
#         "createdAt": {
#             "$date": 1564781410366
#         },
#         "dimension": "organisational",
#         "id": "level-of-innovation",
#         "name": "Level of innovation",
#         "updatedAt": {
#             "$date": 1564781410366
#         }
#     }
# }

# %%
projectCharacteristics = project["characteristics"]
cnames = [*projectCharacteristics]
cnames
# Out:
# ['impact', 'expertise', 'formalism', 'guidance', 'level-of-innovation']

# %%
import pprint
from sklearn.preprocessing import OrdinalEncoder

for cid,pc in projectCharacteristics.items():
    if(pc["rule"] == "preference_list"):
        pass
    elif(pc["rule"] == "exact"):
        pass
    else: #maximum, minimum
        if (cid in characteristics):   
            for cv in characteristics[cid]["characteristicValues"]:
                if (cv["ref"] == pc["ref"]):
                    if (pc["rule"] == "maximum"):
                        pc["value"] = list(reversed(cv["values"]))
                    else:
                        pc["value"] = cv["values"]
                    break
    values = pc["value"] + ["N/A"]
    values.reverse() # ordinal values asc order (smallest to largest)
    enc = OrdinalEncoder(categories=[values])     
    enc.fit([[v] for v in values])
    pc["encoder"] = enc

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(projectCharacteristics)
# Out:
# {   'expertise': {   '_id': {'$oid': '5d461b961e66c81988a999d0'},
#                      'encoder': OrdinalEncoder(categories=[['N/A', 'high', 'normal', 'low']],
#                dtype=<class 'numpy.float64'>),
#                      'id': 'expertise',
#                      'ref': 'default',
#                      'rule': 'minimum',
#                      'value': ['low', 'normal', 'high']},
#     'formalism': {   '_id': {'$oid': '5d461b961e66c81988a999cd'},
#                      'encoder': OrdinalEncoder(categories=[['N/A', 'informal', 'semi-formal', 'formal']],
#                dtype=<class 'numpy.float64'>),
#                      'id': 'formalism',
#                      'ref': 'formal/semi-formal/informal',
#                      'rule': 'preference_list',
#                      'value': ['formal', 'semi-formal', 'informal']},
#     'guidance': {   '_id': {'$oid': '5d461b961e66c81988a999cf'},
#                     'encoder': OrdinalEncoder(categories=[['N/A', 'guidelines', 'heuristics',
#                             'predefined taxonomy']],
#                dtype=<class 'numpy.float64'>),
#                     'id': 'guidance',
#                     'ref': 'predefined taxonomy/heuristics/guidelines',
#                     'rule': 'preference_list',
#                     'value': [   'predefined taxonomy',
#                                  'heuristics',
#                                  'guidelines']},
#     'impact': {   '_id': {'$oid': '5d461b961e66c81988a999d2'},
#                   'encoder': OrdinalEncoder(categories=[['N/A', 'low', 'normal', 'high']],
#                dtype=<class 'numpy.float64'>),
#                   'id': 'impact',
#                   'ref': 'default',
#                   'rule': 'maximum',
#                   'value': ['high', 'normal', 'low']},
#     'level-of-innovation': {   '_id': {'$oid': '5d461b961e66c81988a999d1'},
#                                'encoder': OrdinalEncoder(categories=[['N/A', 'low', 'normal', 'high']],
#                dtype=<class 'numpy.float64'>),
#                                'id': 'level-of-innovation',
#                                'ref': 'default',
#                                'rule': 'maximum',
#                                'value': ['high', 'normal', 'low']}}

# %%
import pandas as pd
df = pd.DataFrame([], columns=cnames)

for m in method_chunks:
    print(m)
    obj = {}
    for cid,pc in projectCharacteristics.items():
        if(cid in m["characteristics"]):
            if(pc["ref"] == m["characteristics"][cid]["ref"]):
                obj[cid] = m["characteristics"][cid]["value"]
    df = df.append(pd.Series(obj, index=df.columns, name=m["id"]))
df.fillna("N/A",inplace=True)
df
# Out:
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781ea9d2'}, 'characteristics': {'approach': {'_id': {'$oid': '5d46e54887e1f131781ea9d4'}, 'id': 'approach', 'ref': 'systemic/exploratory/explanatory', 'value': 'explanatory'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781ea9d6'}, 'id': 'expertise', 'ref': 'default', 'value': 'normal'}, 'formalism': {'_id': {'$oid': '5d46e54887e1f131781ea9d3'}, 'id': 'formalism', 'ref': 'formal/semi-formal/informal', 'value': 'semi-formal'}, 'guidance': {'_id': {'$oid': '5d46e54887e1f131781ea9d5'}, 'id': 'guidance', 'ref': 'predefined taxonomy/heuristics/guidelines', 'value': 'predefined taxonomy'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781ea9d8'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'level-of-innovation': {'_id': {'$oid': '5d46e54887e1f131781ea9d7'}, 'id': 'level-of-innovation', 'ref': 'default', 'value': 'high'}}, 'createdAt': {'$date': 1564927304356}, 'description': 'NFR Framework for IS Security', 'id': 'nfr-framework', 'name': 'NFR Framework', 'provider': 'company-b', 'updatedAt': {'$date': 1564927304356}, 'url': 'http://example.com/NFR-framework'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781ea9d9'}, 'characteristics': {'approach': {'_id': {'$oid': '5d46e54887e1f131781ea9db'}, 'id': 'approach', 'ref': 'systemic/exploratory/explanatory', 'value': 'exploratory'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781ea9dd'}, 'id': 'expertise', 'ref': 'default', 'value': 'high'}, 'formalism': {'_id': {'$oid': '5d46e54887e1f131781ea9da'}, 'id': 'formalism', 'ref': 'formal/semi-formal/informal', 'value': 'formal'}, 'guidance': {'_id': {'$oid': '5d46e54887e1f131781ea9dc'}, 'id': 'guidance', 'ref': 'predefined taxonomy/heuristics/guidelines', 'value': 'heuristics'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781ea9df'}, 'id': 'impact', 'ref': 'default', 'value': 'low'}, 'level-of-innovation': {'_id': {'$oid': '5d46e54887e1f131781ea9de'}, 'id': 'level-of-innovation', 'ref': 'default', 'value': 'high'}}, 'createdAt': {'$date': 1564927304357}, 'description': 'KAOS for IS Security', 'id': 'kaos', 'name': 'KAOS', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304357}, 'url': 'http://example.com/KAOS'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781ea9e0'}, 'characteristics': {'approach': {'_id': {'$oid': '5d46e54887e1f131781ea9e2'}, 'id': 'approach', 'ref': 'systemic/exploratory/explanatory', 'value': 'systemic'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781ea9e3'}, 'id': 'expertise', 'ref': 'default', 'value': 'high'}, 'formalism': {'_id': {'$oid': '5d46e54887e1f131781ea9e1'}, 'id': 'formalism', 'ref': 'formal/semi-formal/informal', 'value': 'formal'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781ea9e5'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'level-of-innovation': {'_id': {'$oid': '5d46e54887e1f131781ea9e4'}, 'id': 'level-of-innovation', 'ref': 'default', 'value': 'low'}}, 'createdAt': {'$date': 1564927304358}, 'description': 'Secure Tropos for IS Security', 'id': 'secure-tropos', 'name': 'Secure Tropos', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304358}, 'url': 'http://example.com/secure-tropos'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781ea9e6'}, 'characteristics': {'expertise': {'_id': {'$oid': '5d46e54887e1f131781ea9e9'}, 'id': 'expertise', 'ref': 'default', 'value': 'normal'}, 'formalism': {'_id': {'$oid': '5d46e54887e1f131781ea9e7'}, 'id': 'formalism', 'ref': 'formal/semi-formal/informal', 'value': 'informal'}, 'guidance': {'_id': {'$oid': '5d46e54887e1f131781ea9e8'}, 'id': 'guidance', 'ref': 'predefined taxonomy/heuristics/guidelines', 'value': 'heuristics'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781ea9eb'}, 'id': 'impact', 'ref': 'default', 'value': 'low'}, 'level-of-innovation': {'_id': {'$oid': '5d46e54887e1f131781ea9ea'}, 'id': 'level-of-innovation', 'ref': 'default', 'value': 'high'}}, 'createdAt': {'$date': 1564927304358}, 'description': 'GBRAM for IS Security', 'id': 'gbram', 'name': 'GBRAM', 'provider': 'company-b', 'updatedAt': {'$date': 1564927304358}, 'url': 'http://example.com/gbram'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781ea9ec'}, 'characteristics': {'approach': {'_id': {'$oid': '5d46e54887e1f131781ea9ee'}, 'id': 'approach', 'ref': 'systemic/exploratory/explanatory', 'value': 'explanatory'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781ea9f0'}, 'id': 'expertise', 'ref': 'default', 'value': 'low'}, 'formalism': {'_id': {'$oid': '5d46e54887e1f131781ea9ed'}, 'id': 'formalism', 'ref': 'formal/semi-formal/informal', 'value': 'informal'}, 'guidance': {'_id': {'$oid': '5d46e54887e1f131781ea9ef'}, 'id': 'guidance', 'ref': 'predefined taxonomy/heuristics/guidelines', 'value': 'guidelines'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781ea9f2'}, 'id': 'impact', 'ref': 'default', 'value': 'normal'}, 'level-of-innovation': {'_id': {'$oid': '5d46e54887e1f131781ea9f1'}, 'id': 'level-of-innovation', 'ref': 'default', 'value': 'high'}}, 'createdAt': {'$date': 1564927304359}, 'description': 'Misuse Cases for IS Security', 'id': 'misuse-cases', 'name': 'Misuse Cases', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304359}, 'url': 'http://example.com/misusecases'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781ea9f3'}, 'characteristics': {'expertise': {'_id': {'$oid': '5d46e54887e1f131781ea9f6'}, 'id': 'expertise', 'ref': 'default', 'value': 'high'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781ea9f4'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'importance': {'_id': {'$oid': '5d46e54887e1f131781ea9f7'}, 'id': 'importance', 'ref': 'default', 'value': 'normal'}, 'management-commitment': {'_id': {'$oid': '5d46e54887e1f131781ea9f8'}, 'id': 'management-commitment', 'ref': 'default', 'value': 'low'}, 'user-involvement': {'_id': {'$oid': '5d46e54887e1f131781ea9f5'}, 'id': 'user-involvement', 'ref': 'default', 'value': 'real'}}, 'createdAt': {'$date': 1564927304360}, 'description': "Acceptance test–driven development (ATDD) is a development methodology based on communication between the business customers, the developers, and the testers. ATDD encompasses many of the same practices as specification by example (SBE),[2][3] behavior-driven development (BDD),[4] example-driven development (EDD), and support-driven development also called story test–driven development (SDD). All these processes aid developers and testers in understanding the customer's needs prior to implementation and allow customers to be able to converse in their own domain language. ATDD is closely related to test-driven development (TDD). It differs by the emphasis on developer-tester-business customer collaboration. ATDD encompasses acceptance testing, but highlights writing acceptance tests before developers begin coding.", 'id': 'acceptance-test-driven-development', 'name': 'Acceptance Test Driven Development', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304360}, 'url': 'http://example.com/AcceptanceTestDrivenDevelopment'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781ea9ff'}, 'characteristics': {'formality': {'_id': {'$oid': '5d46e54887e1f131781eaa02'}, 'id': 'formality', 'ref': 'default', 'value': 'low'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa04'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'resistance-and-conflict': {'_id': {'$oid': '5d46e54887e1f131781eaa03'}, 'id': 'resistance-and-conflict', 'ref': 'default', 'value': 'high'}, 'tracing-project': {'_id': {'$oid': '5d46e54887e1f131781eaa00'}, 'id': 'tracing-project', 'ref': 'default', 'value': 'strong'}, 'variability': {'_id': {'$oid': '5d46e54887e1f131781eaa01'}, 'id': 'variability', 'ref': 'default', 'value': 'high'}}, 'createdAt': {'$date': 1564927304362}, 'description': 'Make incremental improvements to the way of working through regular, repeated retrospectives.', 'id': 'agile-retrospective', 'name': 'Agile Retrospective', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304362}, 'url': 'http://example.com/AgileRetrospective'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa05'}, 'characteristics': {'expertise': {'_id': {'$oid': '5d46e54887e1f131781eaa08'}, 'id': 'expertise', 'ref': 'default', 'value': 'high'}, 'formality': {'_id': {'$oid': '5d46e54887e1f131781eaa06'}, 'id': 'formality', 'ref': 'default', 'value': 'low'}, 'management-commitment': {'_id': {'$oid': '5d46e54887e1f131781eaa09'}, 'id': 'management-commitment', 'ref': 'default', 'value': 'normal'}, 'resistance-and-conflict': {'_id': {'$oid': '5d46e54887e1f131781eaa07'}, 'id': 'resistance-and-conflict', 'ref': 'default', 'value': 'high'}}, 'createdAt': {'$date': 1564927304362}, 'description': 'A self-organizing team maximizes its performance by using a highly-collaborative teaming approach.', 'id': 'agile-teaming', 'name': 'Agile Teaming', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304362}, 'url': 'http://example.com/AgileTeaming'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa11'}, 'characteristics': {'clarity-and-stability': {'_id': {'$oid': '5d46e54887e1f131781eaa14'}, 'id': 'clarity-and-stability', 'ref': 'default', 'value': 'high'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa12'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'importance': {'_id': {'$oid': '5d46e54887e1f131781eaa15'}, 'id': 'importance', 'ref': 'default', 'value': 'high'}, 'management-commitment': {'_id': {'$oid': '5d46e54887e1f131781eaa16'}, 'id': 'management-commitment', 'ref': 'default', 'value': 'high'}, 'user-involvement': {'_id': {'$oid': '5d46e54887e1f131781eaa13'}, 'id': 'user-involvement', 'ref': 'default', 'value': 'real'}}, 'createdAt': {'$date': 1564927304363}, 'description': 'In software engineering, behavior-driven development (BDD) is an Agile software development process that encourages collaboration between developers, QA and non-technical or business participants in a software project. It encourages teams to use conversation and concrete examples to formalize a shared understanding of how the application should behave. Although BDD is principally an idea about how software development should be managed by both business interests and technical insight, the practice of BDD does assume the use of specialized software tools to support the development process. BDD is largely facilitated through the use of a simple domain-specific language (DSL) using natural language constructs (e.g., English-like sentences) that can express the behavior and the expected outcomes. BDD helps to focus on the user’s needs and the system’s expected behavior rather than focusing too much on testing the implementation.', 'id': 'behavior-driven-development', 'name': 'Behavior Driven Development', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304363}, 'url': 'http://example.com/BehaviorDrivenDevelopment'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa17'}, 'characteristics': {'clarity-and-stability': {'_id': {'$oid': '5d46e54887e1f131781eaa1a'}, 'id': 'clarity-and-stability', 'ref': 'default', 'value': 'high'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa18'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'importance': {'_id': {'$oid': '5d46e54887e1f131781eaa1b'}, 'id': 'importance', 'ref': 'default', 'value': 'high'}, 'management-commitment': {'_id': {'$oid': '5d46e54887e1f131781eaa1c'}, 'id': 'management-commitment', 'ref': 'default', 'value': 'high'}, 'user-involvement': {'_id': {'$oid': '5d46e54887e1f131781eaa19'}, 'id': 'user-involvement', 'ref': 'default', 'value': 'real'}}, 'createdAt': {'$date': 1564927304364}, 'description': "Big Design Up Front (BDUF) is a software development approach in which the program's design is to be completed and perfected before that program's implementation is started. It is often associated with the waterfall model of software development. Proponents of waterfall model argue that time spent in designing is a worthwhile investment, with the hope that less time and effort will be spent fixing a bug in the early stages of a software product's lifecycle than when that same bug is found and must be fixed later. That is, it is much easier to fix a requirements bug in the requirements phase than to fix that same bug in the implementation phase, as to fix a requirements bug in the implementation phase requires scrapping at least some of the implementation and design work which has already been completed.", 'id': 'big-design-up-front', 'name': 'Big Design Up Front', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304364}, 'url': 'http://example.com/BigDesignUpFront'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa1d'}, 'characteristics': {'complexity': {'_id': {'$oid': '5d46e54887e1f131781eaa1f'}, 'id': 'complexity', 'ref': 'default', 'value': 'high'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781eaa21'}, 'id': 'expertise', 'ref': 'default', 'value': 'high'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa1e'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'time-pressure': {'_id': {'$oid': '5d46e54887e1f131781eaa22'}, 'id': 'time-pressure', 'ref': 'default', 'value': 'high'}, 'tracing-project': {'_id': {'$oid': '5d46e54887e1f131781eaa20'}, 'id': 'tracing-project', 'ref': 'default', 'value': 'strong'}}, 'createdAt': {'$date': 1564927304365}, 'description': 'Continuous delivery (CD or CDE) is a software engineering approach in which teams produce software in short cycles, ensuring that the software can be reliably released at any time and, when releasing the software, doing so manually. It aims at building, testing, and releasing software with greater speed and frequency. The approach helps reduce the cost, time, and risk of delivering changes by allowing for more incremental updates to applications in production. A straightforward and repeatable deployment process is important for continuous delivery.', 'id': 'continuous-delivery', 'name': 'Continuous Delivery', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304365}, 'url': 'http://example.com/ContinuousDelivery'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa23'}, 'characteristics': {'complexity': {'_id': {'$oid': '5d46e54887e1f131781eaa25'}, 'id': 'complexity', 'ref': 'default', 'value': 'high'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781eaa27'}, 'id': 'expertise', 'ref': 'default', 'value': 'high'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa24'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'time-pressure': {'_id': {'$oid': '5d46e54887e1f131781eaa28'}, 'id': 'time-pressure', 'ref': 'default', 'value': 'high'}, 'tracing-project': {'_id': {'$oid': '5d46e54887e1f131781eaa26'}, 'id': 'tracing-project', 'ref': 'default', 'value': 'strong'}}, 'createdAt': {'$date': 1564927304365}, 'description': "Continuous integration (CI) is the practice of merging all developer working copies to a shared mainline several times a day. Continuous integration involves integrating early and often, so as to avoid the pitfalls of 'integration hell'.", 'id': 'continuous-integration', 'name': 'Continuous Integration', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304365}, 'url': 'http://example.com/ContinuousIntegration'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa29'}, 'characteristics': {'clarity-and-stability': {'_id': {'$oid': '5d46e54887e1f131781eaa2d'}, 'id': 'clarity-and-stability', 'ref': 'default', 'value': 'high'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781eaa2c'}, 'id': 'expertise', 'ref': 'default', 'value': 'low'}, 'formality': {'_id': {'$oid': '5d46e54887e1f131781eaa2b'}, 'id': 'formality', 'ref': 'default', 'value': 'low'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa2e'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'management-commitment': {'_id': {'$oid': '5d46e54887e1f131781eaa30'}, 'id': 'management-commitment', 'ref': 'default', 'value': 'high'}, 'time-pressure': {'_id': {'$oid': '5d46e54887e1f131781eaa2f'}, 'id': 'time-pressure', 'ref': 'default', 'value': 'high'}, 'tracing-project': {'_id': {'$oid': '5d46e54887e1f131781eaa2a'}, 'id': 'tracing-project', 'ref': 'default', 'value': 'strong'}}, 'createdAt': {'$date': 1564927304365}, 'description': 'Use short, daily whole-team meetings to coordinate the work of the team and raise impediments.', 'id': 'daily-stand-up', 'name': 'Daily Stand-Up', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304365}, 'url': 'http://example.com/DailyStandUp'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa31'}, 'characteristics': {'complexity': {'_id': {'$oid': '5d46e54887e1f131781eaa33'}, 'id': 'complexity', 'ref': 'default', 'value': 'normal'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781eaa35'}, 'id': 'expertise', 'ref': 'default', 'value': 'low'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa32'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'resistance-and-conflict': {'_id': {'$oid': '5d46e54887e1f131781eaa36'}, 'id': 'resistance-and-conflict', 'ref': 'default', 'value': 'high'}, 'tracing-project': {'_id': {'$oid': '5d46e54887e1f131781eaa34'}, 'id': 'tracing-project', 'ref': 'default', 'value': 'strong'}}, 'createdAt': {'$date': 1564927304365}, 'description': 'Agile software development technique in which two programmers work together at one workstation. One, the driver, writes code while the other, the observer or navigator,reviews each line of code as it is typed in. The two programmers switch roles frequently. While reviewing, the observer also considers the strategic direction of the work, coming up with ideas for improvements and likely future problems to address. This is intended to free the driver to focus all of their attention on the tactical aspects of completing the current task, using the observer as a safety net and guide. Pair programming increases the man-hours required to deliver code compared to programmers working individually. Experiments yielded diverse results, suggesting increases of between 15% and 100%. However, the resulting code has about 15% fewer defects. Along with code development time, other factors like field support costs and quality assurance also figure in to the return on investment.', 'id': 'pair-programming', 'name': 'Pair Programming', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304366}, 'url': 'http://example.com/PairProgramming'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa3d'}, 'characteristics': {'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa3f'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'importance': {'_id': {'$oid': '5d46e54887e1f131781eaa40'}, 'id': 'importance', 'ref': 'default', 'value': 'normal'}, 'management-commitment': {'_id': {'$oid': '5d46e54887e1f131781eaa41'}, 'id': 'management-commitment', 'ref': 'default', 'value': 'high'}, 'tracing-project': {'_id': {'$oid': '5d46e54887e1f131781eaa3e'}, 'id': 'tracing-project', 'ref': 'default', 'value': 'strong'}}, 'createdAt': {'$date': 1564927304366}, 'description': 'Own, evolve and communicate the vision, and guide the evolution of the product to achieve the vision.', 'id': 'product-ownership', 'name': 'Product Ownership', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304366}, 'url': 'http://example.com/ProductOwnership'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa42'}, 'characteristics': {'clarity-and-stability': {'_id': {'$oid': '5d46e54887e1f131781eaa45'}, 'id': 'clarity-and-stability', 'ref': 'default', 'value': 'high'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa43'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'importance': {'_id': {'$oid': '5d46e54887e1f131781eaa46'}, 'id': 'importance', 'ref': 'default', 'value': 'high'}, 'management-commitment': {'_id': {'$oid': '5d46e54887e1f131781eaa47'}, 'id': 'management-commitment', 'ref': 'default', 'value': 'high'}, 'user-involvement': {'_id': {'$oid': '5d46e54887e1f131781eaa44'}, 'id': 'user-involvement', 'ref': 'default', 'value': 'real'}}, 'createdAt': {'$date': 1564927304366}, 'description': 'Specification by example (SBE) is a collaborative approach to defining requirements and business-oriented functional tests for software products based on capturing and illustrating requirements using realistic examples instead of abstract statements. It is applied in the context of agile software development methods, in particular behavior-driven development. This approach is particularly successful for managing requirements and functional tests on large-scale projects of significant domain and organisational complexity.', 'id': 'specification-by-example', 'name': 'Specification By Example', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304366}, 'url': 'http://example.com/SpecificationByExample'}
# {'__v': 0, '_id': {'$oid': '5d46e54887e1f131781eaa48'}, 'characteristics': {'complexity': {'_id': {'$oid': '5d46e54887e1f131781eaa4a'}, 'id': 'complexity', 'ref': 'default', 'value': 'high'}, 'dependency': {'_id': {'$oid': '5d46e54887e1f131781eaa4d'}, 'id': 'dependency', 'ref': 'default', 'value': 'high'}, 'expertise': {'_id': {'$oid': '5d46e54887e1f131781eaa4c'}, 'id': 'expertise', 'ref': 'default', 'value': 'high'}, 'impact': {'_id': {'$oid': '5d46e54887e1f131781eaa49'}, 'id': 'impact', 'ref': 'default', 'value': 'high'}, 'tracing-project': {'_id': {'$oid': '5d46e54887e1f131781eaa4b'}, 'id': 'tracing-project', 'ref': 'default', 'value': 'strong'}}, 'createdAt': {'$date': 1564927304366}, 'description': 'Test-driven development (TDD) is a software development process that relies on the repetition of a very short development cycle: requirements are turned into very specific test cases, then the software is improved to pass the new tests, only. This is opposed to software development that allows software to be added that is not proven to meet requirements. Writing the tests first: The tests should be written before the functionality that is to be tested. This has been claimed to have many benefits. It helps ensure that the application is written for testability, as the developers must consider how to test the application from the outset rather than adding it later. It also ensures that tests for every feature get written. Additionally, writing the tests first leads to a deeper and earlier understanding of the product requirements, ensures the effectiveness of the test code, and maintains a continual focus on software quality.', 'id': 'test-driven-development', 'name': 'Test Driven Development', 'provider': 'company-a', 'updatedAt': {'$date': 1564927304366}, 'url': 'http://example.com/TestDrivenDevelopment'}
#                                     impact expertise    formalism  \
# nfr-framework                         high    normal  semi-formal
# kaos                                   low      high       formal
# secure-tropos                         high      high       formal
# gbram                                  low    normal     informal
# misuse-cases                        normal       low     informal
# acceptance-test-driven-development    high      high          N/A
# agile-retrospective                   high       N/A          N/A
# agile-teaming                          N/A      high          N/A
# behavior-driven-development           high       N/A          N/A
# big-design-up-front                   high       N/A          N/A
# continuous-delivery                   high      high          N/A
# continuous-integration                high      high          N/A
# daily-stand-up                        high       low          N/A
# pair-programming                      high       low          N/A
# product-ownership                     high       N/A          N/A
# specification-by-example              high       N/A          N/A
# test-driven-development               high      high          N/A
#
#                                                guidance level-of-innovation
# nfr-framework                       predefined taxonomy                high
# kaos                                         heuristics                high
# secure-tropos                                       N/A                 low
# gbram                                        heuristics                high
# misuse-cases                                 guidelines                high
# acceptance-test-driven-development                  N/A                 N/A
# agile-retrospective                                 N/A                 N/A
# agile-teaming                                       N/A                 N/A
# behavior-driven-development                         N/A                 N/A
# big-design-up-front                                 N/A                 N/A
# continuous-delivery                                 N/A                 N/A
# continuous-integration                              N/A                 N/A
# daily-stand-up                                      N/A                 N/A
# pair-programming                                    N/A                 N/A
# product-ownership                                   N/A                 N/A
# specification-by-example                            N/A                 N/A
# test-driven-development                             N/A                 N/A

# %%
encoded = df.copy()
for key, value in encoded.items(): 
    values = [v if v in projectCharacteristics[key]["value"] else "N/A" for v in value]
    encoded.loc[:,key]=projectCharacteristics[key]["encoder"].transform([[v] for v in values])
display(encoded)
encoded = encoded.loc[:, (encoded != 0).any(axis=0)]
display(encoded)
# Out:
#                                     impact  expertise  formalism  guidance  \
# nfr-framework                          3.0        2.0        2.0       3.0
# kaos                                   1.0        1.0        3.0       2.0
# secure-tropos                          3.0        1.0        3.0       0.0
# gbram                                  1.0        2.0        1.0       2.0
# misuse-cases                           2.0        3.0        1.0       1.0
# acceptance-test-driven-development     3.0        1.0        0.0       0.0
# agile-retrospective                    3.0        0.0        0.0       0.0
# agile-teaming                          0.0        1.0        0.0       0.0
# behavior-driven-development            3.0        0.0        0.0       0.0
# big-design-up-front                    3.0        0.0        0.0       0.0
# continuous-delivery                    3.0        1.0        0.0       0.0
# continuous-integration                 3.0        1.0        0.0       0.0
# daily-stand-up                         3.0        3.0        0.0       0.0
# pair-programming                       3.0        3.0        0.0       0.0
# product-ownership                      3.0        0.0        0.0       0.0
# specification-by-example               3.0        0.0        0.0       0.0
# test-driven-development                3.0        1.0        0.0       0.0
#
#                                     level-of-innovation
# nfr-framework                                       3.0
# kaos                                                3.0
# secure-tropos                                       1.0
# gbram                                               3.0
# misuse-cases                                        3.0
# acceptance-test-driven-development                  0.0
# agile-retrospective                                 0.0
# agile-teaming                                       0.0
# behavior-driven-development                         0.0
# big-design-up-front                                 0.0
# continuous-delivery                                 0.0
# continuous-integration                              0.0
# daily-stand-up                                      0.0
# pair-programming                                    0.0
# product-ownership                                   0.0
# specification-by-example                            0.0
# test-driven-development                             0.0
#                                     impact  expertise  formalism  guidance  \
# nfr-framework                          3.0        2.0        2.0       3.0
# kaos                                   1.0        1.0        3.0       2.0
# secure-tropos                          3.0        1.0        3.0       0.0
# gbram                                  1.0        2.0        1.0       2.0
# misuse-cases                           2.0        3.0        1.0       1.0
# acceptance-test-driven-development     3.0        1.0        0.0       0.0
# agile-retrospective                    3.0        0.0        0.0       0.0
# agile-teaming                          0.0        1.0        0.0       0.0
# behavior-driven-development            3.0        0.0        0.0       0.0
# big-design-up-front                    3.0        0.0        0.0       0.0
# continuous-delivery                    3.0        1.0        0.0       0.0
# continuous-integration                 3.0        1.0        0.0       0.0
# daily-stand-up                         3.0        3.0        0.0       0.0
# pair-programming                       3.0        3.0        0.0       0.0
# product-ownership                      3.0        0.0        0.0       0.0
# specification-by-example               3.0        0.0        0.0       0.0
# test-driven-development                3.0        1.0        0.0       0.0
#
#                                     level-of-innovation
# nfr-framework                                       3.0
# kaos                                                3.0
# secure-tropos                                       1.0
# gbram                                               3.0
# misuse-cases                                        3.0
# acceptance-test-driven-development                  0.0
# agile-retrospective                                 0.0
# agile-teaming                                       0.0
# behavior-driven-development                         0.0
# big-design-up-front                                 0.0
# continuous-delivery                                 0.0
# continuous-integration                              0.0
# daily-stand-up                                      0.0
# pair-programming                                    0.0
# product-ownership                                   0.0
# specification-by-example                            0.0
# test-driven-development                             0.0

# %% [markdown]
# ### MADM

# %%
from skcriteria import Data, MAX
from skcriteria.madm import simple, closeness

optimal_senses = []
weights = []
for cid,pc in encoded.items():
    optimal_senses.append(MAX)
    weights.append(projectCharacteristics[cid].get("weight",1))

data = Data(encoded.values, optimal_senses, 
            weights=weights,
            anames=encoded.index,
            cnames=encoded.columns)
display(data)
# Out:
#             ALT./CRIT.               impact (max) W.1    expertise (max) W.1    formalism (max) W.1    guidance (max) W.1    level-of-innovation (max) W.1
# ----------------------------------  ------------------  ---------------------  ---------------------  --------------------  -------------------------------
#           nfr-framework                     3                     2                      2                     3                           3
#                kaos                         1                     1                      3                     2                           3
#           secure-tropos                     3                     1                      3                     0                           1
#               gbram                         1                     2                      1                     2                           3
#            misuse-cases                     2                     3                      1                     1                           3
# acceptance-test-driven-development          3                     1                      0                     0                           0
#        agile-retrospective                  3                     0                      0                     0                           0
#           agile-teaming                     0                     1                      0                     0                           0
#    behavior-driven-development              3                     0                      0                     0                           0
#        big-design-up-front                  3                     0                      0                     0                           0
#        continuous-delivery                  3                     1                      0                     0                           0
#       continuous-integration                3                     1                      0                     0                           0
#           daily-stand-up                    3                     3                      0                     0                           0
#          pair-programming                   3                     3                      0                     0                           0
#         product-ownership                   3                     0                      0                     0                           0
#      specification-by-example               3                     0                      0                     0                           0
#      test-driven-development                3                     1                      0                     0                           0

# %% [markdown]
# ### WeightedSum

# %%
model = simple.WeightedSum(mnorm="vector",wnorm="sum")
de = model.decide(data)

display(de)

print(de.e_)
print("Points:",de.e_.points)
# Out:
# WeightedSum (mnorm=vector, wnorm=sum) - Solution:
#             ALT./CRIT.               impact (max) W.1    expertise (max) W.1    formalism (max) W.1    guidance (max) W.1    level-of-innovation (max) W.1    Rank
# ----------------------------------  ------------------  ---------------------  ---------------------  --------------------  -------------------------------  ------
#           nfr-framework                     3                     2                      2                     3                           3                   1
#                kaos                         1                     1                      3                     2                           3                   2
#           secure-tropos                     3                     1                      3                     0                           1                   5
#               gbram                         1                     2                      1                     2                           3                   4
#            misuse-cases                     2                     3                      1                     1                           3                   3
# acceptance-test-driven-development          3                     1                      0                     0                           0                   8
#        agile-retrospective                  3                     0                      0                     0                           0                   12
#           agile-teaming                     0                     1                      0                     0                           0                   17
#    behavior-driven-development              3                     0                      0                     0                           0                   13
#        big-design-up-front                  3                     0                      0                     0                           0                   14
#        continuous-delivery                  3                     1                      0                     0                           0                   9
#       continuous-integration                3                     1                      0                     0                           0                   10
#           daily-stand-up                    3                     3                      0                     0                           0                   6
#          pair-programming                   3                     3                      0                     0                           0                   7
#         product-ownership                   3                     0                      0                     0                           0                   15
#      specification-by-example               3                     0                      0                     0                           0                   16
#      test-driven-development                3                     1                      0                     0                           0                   11
# Extra(points)
# Points: [0.43753192 0.36428885 0.24031513 0.31349986 0.31525347 0.08496085
#  0.05410018 0.03086067 0.05410018 0.05410018 0.08496085 0.08496085
#  0.14668219 0.14668219 0.05410018 0.05410018 0.08496085]

# %% [markdown]
# ### TOPSIS

# %%
model2 = closeness.TOPSIS(mnorm="vector",wnorm="sum")
de2 = model2.decide(data)

display(de2)
print(de2.e_)
print("Ideal:", de2.e_.ideal)
print("Anti-Ideal:", de2.e_.anti_ideal)
print("Closeness:", de2.e_.closeness)
# Out:
# TOPSIS (mnorm=vector, wnorm=sum) - Solution:
#             ALT./CRIT.               impact (max) W.1    expertise (max) W.1    formalism (max) W.1    guidance (max) W.1    level-of-innovation (max) W.1    Rank
# ----------------------------------  ------------------  ---------------------  ---------------------  --------------------  -------------------------------  ------
#           nfr-framework                     3                     2                      2                     3                           3                   1
#                kaos                         1                     1                      3                     2                           3                   2
#           secure-tropos                     3                     1                      3                     0                           1                   5
#               gbram                         1                     2                      1                     2                           3                   3
#            misuse-cases                     2                     3                      1                     1                           3                   4
# acceptance-test-driven-development          3                     1                      0                     0                           0                   8
#        agile-retrospective                  3                     0                      0                     0                           0                   12
#           agile-teaming                     0                     1                      0                     0                           0                   17
#    behavior-driven-development              3                     0                      0                     0                           0                   13
#        big-design-up-front                  3                     0                      0                     0                           0                   14
#        continuous-delivery                  3                     1                      0                     0                           0                   9
#       continuous-integration                3                     1                      0                     0                           0                   10
#           daily-stand-up                    3                     3                      0                     0                           0                   6
#          pair-programming                   3                     3                      0                     0                           0                   7
#         product-ownership                   3                     0                      0                     0                           0                   15
#      specification-by-example               3                     0                      0                     0                           0                   16
#      test-driven-development                3                     1                      0                     0                           0                   11
# Extra(ideal, anti_ideal, closeness)
# Ideal: [0.05410018 0.09258201 0.12247449 0.14142136 0.09863939]
# Anti-Ideal: [0. 0. 0. 0. 0.]
# Closeness: [0.80230064 0.68568587 0.45720142 0.59684513 0.54878222 0.2203942
#  0.18984476 0.11974401 0.18984476 0.18984476 0.2203942  0.2203942
#  0.3364351  0.3364351  0.18984476 0.18984476 0.2203942 ]

# %% [markdown]
# ### RESPONSE

# %%
res = {}
res["project"] = project

z = [{"id":de._data._anames[i], "score":de.e_.points[i],"rank":int(de._rank[i])} for i in range(0,len(de.mtx))]
wsm = {
    "model": "WeightedSum",
    "methodChunks": sorted(z, key = lambda x: x["rank"])
}

z2 = [{"id":de2._data._anames[i], "score":de2.e_.closeness[i],"rank":int(de2._rank[i])} for i in range(0,len(de2.mtx))]
topsis = {
    "model": "TOPSIS",
    "methodChunks": sorted(z2, key = lambda x: x["rank"])
}

res["result"] = [
    wsm,
    topsis
]

res
# Out:
# {'project': {'__v': 0,
#   '_id': {'$oid': '5d461b961e66c81988a999cc'},
#   'characteristics': {'impact': {'_id': {'$oid': '5d461b961e66c81988a999d2'},
#     'id': 'impact',
#     'ref': 'default',
#     'rule': 'maximum',
#     'value': ['high', 'normal', 'low'],
#     'encoder': OrdinalEncoder(categories=[['N/A', 'low', 'normal', 'high']],
#                    dtype=<class 'numpy.float64'>)},
#    'expertise': {'_id': {'$oid': '5d461b961e66c81988a999d0'},
#     'id': 'expertise',
#     'ref': 'default',
#     'rule': 'minimum',
#     'value': ['low', 'normal', 'high'],
#     'encoder': OrdinalEncoder(categories=[['N/A', 'high', 'normal', 'low']],
#                    dtype=<class 'numpy.float64'>)},
#    'formalism': {'_id': {'$oid': '5d461b961e66c81988a999cd'},
#     'id': 'formalism',
#     'ref': 'formal/semi-formal/informal',
#     'rule': 'preference_list',
#     'value': ['formal', 'semi-formal', 'informal'],
#     'encoder': OrdinalEncoder(categories=[['N/A', 'informal', 'semi-formal', 'formal']],
#                    dtype=<class 'numpy.float64'>)},
#    'guidance': {'_id': {'$oid': '5d461b961e66c81988a999cf'},
#     'id': 'guidance',
#     'ref': 'predefined taxonomy/heuristics/guidelines',
#     'rule': 'preference_list',
#     'value': ['predefined taxonomy', 'heuristics', 'guidelines'],
#     'encoder': OrdinalEncoder(categories=[['N/A', 'guidelines', 'heuristics',
#                                 'predefined taxonomy']],
#                    dtype=<class 'numpy.float64'>)},
#    'level-of-innovation': {'_id': {'$oid': '5d461b961e66c81988a999d1'},
#     'id': 'level-of-innovation',
#     'ref': 'default',
#     'rule': 'maximum',
#     'value': ['high', 'normal', 'low'],
#     'encoder': OrdinalEncoder(categories=[['N/A', 'low', 'normal', 'high']],
#                    dtype=<class 'numpy.float64'>)}},
#   'createdAt': {'$date': 1564875671242},
#   'description': 'IS security chunks evaluation.',
#   'id': 'company-a-ltd/test-project',
#   'name': 'Test Project',
#   'project': 'test-project',
#   'provider': 'company-a-ltd',
#   'updatedAt': {'$date': 1564875671242}},
#  'result': [{'model': 'WeightedSum',
#    'methodChunks': [{'id': 'nfr-framework',
#      'score': 0.43753192477817926,
#      'rank': 1},
#     {'id': 'kaos', 'score': 0.36428884636634673, 'rank': 2},
#     {'id': 'misuse-cases', 'score': 0.3152534688726563, 'rank': 3},
#     {'id': 'gbram', 'score': 0.31349985826599247, 'rank': 4},
#     {'id': 'secure-tropos', 'score': 0.24031513267269472, 'rank': 5},
#     {'id': 'daily-stand-up', 'score': 0.1466821880573011, 'rank': 6},
#     {'id': 'pair-programming', 'score': 0.1466821880573011, 'rank': 7},
#     {'id': 'acceptance-test-driven-development',
#      'score': 0.08496084807246432,
#      'rank': 8},
#     {'id': 'continuous-delivery', 'score': 0.08496084807246432, 'rank': 9},
#     {'id': 'continuous-integration', 'score': 0.08496084807246432, 'rank': 10},
#     {'id': 'test-driven-development',
#      'score': 0.08496084807246432,
#      'rank': 11},
#     {'id': 'agile-retrospective', 'score': 0.05410017808004594, 'rank': 12},
#     {'id': 'behavior-driven-development',
#      'score': 0.05410017808004594,
#      'rank': 13},
#     {'id': 'big-design-up-front', 'score': 0.05410017808004594, 'rank': 14},
#     {'id': 'product-ownership', 'score': 0.05410017808004594, 'rank': 15},
#     {'id': 'specification-by-example',
#      'score': 0.05410017808004594,
#      'rank': 16},
#     {'id': 'agile-teaming', 'score': 0.030860669992418384, 'rank': 17}]},
#   {'model': 'TOPSIS',
#    'methodChunks': [{'id': 'nfr-framework',
#      'score': 0.8023006395722284,
#      'rank': 1},
#     {'id': 'kaos', 'score': 0.6856858735448752, 'rank': 2},
#     {'id': 'gbram', 'score': 0.5968451320201774, 'rank': 3},
#     {'id': 'misuse-cases', 'score': 0.5487822242400944, 'rank': 4},
#     {'id': 'secure-tropos', 'score': 0.457201420238231, 'rank': 5},
#     {'id': 'daily-stand-up', 'score': 0.3364350953442121, 'rank': 6},
#     {'id': 'pair-programming', 'score': 0.3364350953442121, 'rank': 7},
#     {'id': 'acceptance-test-driven-development',
#      'score': 0.2203942044650762,
#      'rank': 8},
#     {'id': 'continuous-delivery', 'score': 0.2203942044650762, 'rank': 9},
#     {'id': 'continuous-integration', 'score': 0.2203942044650762, 'rank': 10},
#     {'id': 'test-driven-development', 'score': 0.2203942044650762, 'rank': 11},
#     {'id': 'agile-retrospective', 'score': 0.18984476073382214, 'rank': 12},
#     {'id': 'behavior-driven-development',
#      'score': 0.18984476073382214,
#      'rank': 13},
#     {'id': 'big-design-up-front', 'score': 0.18984476073382214, 'rank': 14},
#     {'id': 'product-ownership', 'score': 0.18984476073382214, 'rank': 15},
#     {'id': 'specification-by-example',
#      'score': 0.18984476073382214,
#      'rank': 16},
#     {'id': 'agile-teaming', 'score': 0.11974400625036472, 'rank': 17}]}]}
