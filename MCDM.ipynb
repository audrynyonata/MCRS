# %% [markdown]
# ### DUMMY DATA

# %%
project_dict_string ='{"__v":0,"_id":{"$oid":"5d461b961e66c81988a999cc"},"characteristics":{"approach":{"_id":{"$oid":"5d461b961e66c81988a999ce"},"id":"approach","ref":"systemic/exploratory/explanatory","rule":"preference_list","value":["systemic","exploratory","explanatory"]},"expertise":{"_id":{"$oid":"5d461b961e66c81988a999d0"},"id":"expertise","ref":"default","rule":"minimum","value":[]},"formalism":{"_id":{"$oid":"5d461b961e66c81988a999cd"},"id":"formalism","ref":"formal/semi-formal/informal","rule":"preference_list","value":["formal","semi-formal","informal"]},"guidance":{"_id":{"$oid":"5d461b961e66c81988a999cf"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","rule":"preference_list","value":["predefined taxonomy","heuristics","guidelines"]},"impact":{"_id":{"$oid":"5d461b961e66c81988a999d2"},"id":"impact","ref":"default","rule":"maximum","value":[]},"level-of-innovation":{"_id":{"$oid":"5d461b961e66c81988a999d1"},"id":"level-of-innovation","ref":"default","rule":"maximum","value":[]}},"createdAt":{"$date":1564875671242},"description":"IS security chunks evaluation.","id":"company-a-ltd/test-project","name":"Test Project","project":"test-project","provider":"company-a-ltd","updatedAt":{"$date":1564875671242}}'

# %%
characteristics_dict_string = '{"approach":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28eb7"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28eb8"},"isQuantifiable":false,"ref":"systemic/exploratory/explanatory","values":["systemic","exploratory","explanatory"]}],"createdAt":{"$date":1564781410365},"id":"approach","name":"Approach","updatedAt":{"$date":1564781410365}},"expertise":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28ece"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28ed0"},"isQuantifiable":true,"ref":"default","values":["low","normal","high"]},{"_id":{"$oid":"5d44ab62ac770313a0f28ecf"},"isQuantifiable":false,"ref":"tester/developer/designer/analyst","values":["tester","developer","designer","analyst"]}],"createdAt":{"$date":1564781410366},"dimension":"human","id":"expertise","name":"Expertise","updatedAt":{"$date":1564781410366}},"formalism":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28eb9"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28eba"},"isQuantifiable":false,"ref":"formal/semi-formal/informal","values":["formal","semi-formal","informal"]}],"createdAt":{"$date":1564781410365},"id":"formalism","name":"Formalism","updatedAt":{"$date":1564781410365}},"guidance":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28eb5"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28eb6"},"isQuantifiable":false,"ref":"predefined taxonomy/heuristics/guidelines","values":["predefined taxonomy","heuristics","guidelines"]}],"createdAt":{"$date":1564781410364},"id":"guidance","name":"Guidance","updatedAt":{"$date":1564781410364}},"impact":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28ebf"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28ec0"},"isQuantifiable":true,"ref":"default","values":["low","normal","high"]}],"createdAt":{"$date":1564781410365},"dimension":"organisational","id":"impact","name":"Impact","updatedAt":{"$date":1564781410365}},"level-of-innovation":{"__v":0,"_id":{"$oid":"5d44ab62ac770313a0f28ec9"},"characteristicValues":[{"_id":{"$oid":"5d44ab62ac770313a0f28ecb"},"isQuantifiable":true,"ref":"default","values":["low","normal","high"]},{"_id":{"$oid":"5d44ab62ac770313a0f28eca"},"isQuantifiable":false,"ref":"business/technology","values":["business innovation","technology innovation"]}],"createdAt":{"$date":1564781410366},"dimension":"organisational","id":"level-of-innovation","name":"Level of innovation","updatedAt":{"$date":1564781410366}}}'

# %%
method_chunks_dict_string = '{"acceptance-test-driven-development":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06c0"},"characteristics":{"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06c3"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06c1"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d473b1834653918d4ab06c4"},"id":"importance","ref":"default","value":"normal"},"management-commitment":{"_id":{"$oid":"5d473b1834653918d4ab06c5"},"id":"management-commitment","ref":"default","value":"low"},"user-involvement":{"_id":{"$oid":"5d473b1834653918d4ab06c2"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564949272731},"description":"Acceptance test–driven development (ATDD) is a development methodology based on communication between the business customers, the developers, and the testers. ATDD encompasses many of the same practices as specification by example (SBE),[2][3] behavior-driven development (BDD),[4] example-driven development (EDD), and support-driven development also called story test–driven development (SDD). All these processes aid developers and testers in understanding the customer\'s needs prior to implementation and allow customers to be able to converse in their own domain language. ATDD is closely related to test-driven development (TDD). It differs by the emphasis on developer-tester-business customer collaboration. ATDD encompasses acceptance testing, but highlights writing acceptance tests before developers begin coding.","id":"acceptance-test-driven-development","name":"Acceptance Test Driven Development","provider":"company-a","updatedAt":{"$date":1564949272731},"url":"http://example.com/AcceptanceTestDrivenDevelopment"},"agile-retrospective":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06cc"},"characteristics":{"formality":{"_id":{"$oid":"5d473b1834653918d4ab06cf"},"id":"formality","ref":"default","value":"low"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06d1"},"id":"impact","ref":"default","value":"high"},"resistance-and-conflict":{"_id":{"$oid":"5d473b1834653918d4ab06d0"},"id":"resistance-and-conflict","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d473b1834653918d4ab06cd"},"id":"tracing-project","ref":"default","value":"strong"},"variability":{"_id":{"$oid":"5d473b1834653918d4ab06ce"},"id":"variability","ref":"default","value":"high"}},"createdAt":{"$date":1564949272735},"description":"Make incremental improvements to the way of working through regular, repeated retrospectives.","id":"agile-retrospective","name":"Agile Retrospective","provider":"company-a","updatedAt":{"$date":1564949272735},"url":"http://example.com/AgileRetrospective"},"agile-teaming":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06d2"},"characteristics":{"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06d5"},"id":"expertise","ref":"default","value":"high"},"formality":{"_id":{"$oid":"5d473b1834653918d4ab06d3"},"id":"formality","ref":"default","value":"low"},"management-commitment":{"_id":{"$oid":"5d473b1834653918d4ab06d6"},"id":"management-commitment","ref":"default","value":"normal"},"resistance-and-conflict":{"_id":{"$oid":"5d473b1834653918d4ab06d4"},"id":"resistance-and-conflict","ref":"default","value":"high"}},"createdAt":{"$date":1564949272736},"description":"A self-organizing team maximizes its performance by using a highly-collaborative teaming approach.","id":"agile-teaming","name":"Agile Teaming","provider":"company-a","updatedAt":{"$date":1564949272736},"url":"http://example.com/AgileTeaming"},"behavior-driven-development":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06de"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d473b1834653918d4ab06e1"},"id":"clarity-and-stability","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06df"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d473b1834653918d4ab06e2"},"id":"importance","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d473b1834653918d4ab06e3"},"id":"management-commitment","ref":"default","value":"high"},"user-involvement":{"_id":{"$oid":"5d473b1834653918d4ab06e0"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564949272737},"description":"In software engineering, behavior-driven development (BDD) is an Agile software development process that encourages collaboration between developers, QA and non-technical or business participants in a software project. It encourages teams to use conversation and concrete examples to formalize a shared understanding of how the application should behave. Although BDD is principally an idea about how software development should be managed by both business interests and technical insight, the practice of BDD does assume the use of specialized software tools to support the development process. BDD is largely facilitated through the use of a simple domain-specific language (DSL) using natural language constructs (e.g., English-like sentences) that can express the behavior and the expected outcomes. BDD helps to focus on the user’s needs and the system’s expected behavior rather than focusing too much on testing the implementation.","id":"behavior-driven-development","name":"Behavior Driven Development","provider":"company-a","updatedAt":{"$date":1564949272737},"url":"http://example.com/BehaviorDrivenDevelopment"},"big-design-up-front":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06e4"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d473b1834653918d4ab06e7"},"id":"clarity-and-stability","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06e5"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d473b1834653918d4ab06e8"},"id":"importance","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d473b1834653918d4ab06e9"},"id":"management-commitment","ref":"default","value":"high"},"user-involvement":{"_id":{"$oid":"5d473b1834653918d4ab06e6"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564949272738},"description":"Big Design Up Front (BDUF) is a software development approach in which the program\'s design is to be completed and perfected before that program\'s implementation is started. It is often associated with the waterfall model of software development. Proponents of waterfall model argue that time spent in designing is a worthwhile investment, with the hope that less time and effort will be spent fixing a bug in the early stages of a software product\'s lifecycle than when that same bug is found and must be fixed later. That is, it is much easier to fix a requirements bug in the requirements phase than to fix that same bug in the implementation phase, as to fix a requirements bug in the implementation phase requires scrapping at least some of the implementation and design work which has already been completed.","id":"big-design-up-front","name":"Big Design Up Front","provider":"company-a","updatedAt":{"$date":1564949272738},"url":"http://example.com/BigDesignUpFront"},"continuous-delivery":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06ea"},"characteristics":{"complexity":{"_id":{"$oid":"5d473b1834653918d4ab06ec"},"id":"complexity","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06ee"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06eb"},"id":"impact","ref":"default","value":"high"},"time-pressure":{"_id":{"$oid":"5d473b1834653918d4ab06ef"},"id":"time-pressure","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d473b1834653918d4ab06ed"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564949272742},"description":"Continuous delivery (CD or CDE) is a software engineering approach in which teams produce software in short cycles, ensuring that the software can be reliably released at any time and, when releasing the software, doing so manually. It aims at building, testing, and releasing software with greater speed and frequency. The approach helps reduce the cost, time, and risk of delivering changes by allowing for more incremental updates to applications in production. A straightforward and repeatable deployment process is important for continuous delivery.","id":"continuous-delivery","name":"Continuous Delivery","provider":"company-a","updatedAt":{"$date":1564949272742},"url":"http://example.com/ContinuousDelivery"},"continuous-integration":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06f0"},"characteristics":{"complexity":{"_id":{"$oid":"5d473b1834653918d4ab06f2"},"id":"complexity","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06f4"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06f1"},"id":"impact","ref":"default","value":"high"},"time-pressure":{"_id":{"$oid":"5d473b1834653918d4ab06f5"},"id":"time-pressure","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d473b1834653918d4ab06f3"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564949272742},"description":"Continuous integration (CI) is the practice of merging all developer working copies to a shared mainline several times a day. Continuous integration involves integrating early and often, so as to avoid the pitfalls of \'integration hell\'.","id":"continuous-integration","name":"Continuous Integration","provider":"company-a","updatedAt":{"$date":1564949272742},"url":"http://example.com/ContinuousIntegration"},"daily-stand-up":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06f6"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d473b1834653918d4ab06fa"},"id":"clarity-and-stability","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06f9"},"id":"expertise","ref":"default","value":"low"},"formality":{"_id":{"$oid":"5d473b1834653918d4ab06f8"},"id":"formality","ref":"default","value":"low"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06fb"},"id":"impact","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d473b1834653918d4ab06fd"},"id":"management-commitment","ref":"default","value":"high"},"time-pressure":{"_id":{"$oid":"5d473b1834653918d4ab06fc"},"id":"time-pressure","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d473b1834653918d4ab06f7"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564949272743},"description":"Use short, daily whole-team meetings to coordinate the work of the team and raise impediments.","id":"daily-stand-up","name":"Daily Stand-Up","provider":"company-a","updatedAt":{"$date":1564949272743},"url":"http://example.com/DailyStandUp"},"gbram":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06b3"},"characteristics":{"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06b6"},"id":"expertise","ref":"default","value":"normal"},"formalism":{"_id":{"$oid":"5d473b1834653918d4ab06b4"},"id":"formalism","ref":"formal/semi-formal/informal","value":"informal"},"guidance":{"_id":{"$oid":"5d473b1834653918d4ab06b5"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"heuristics"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06b8"},"id":"impact","ref":"default","value":"low"},"level-of-innovation":{"_id":{"$oid":"5d473b1834653918d4ab06b7"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564949272727},"description":"GBRAM for IS Security","id":"gbram","name":"GBRAM","provider":"company-b","updatedAt":{"$date":1564949272727},"url":"http://example.com/gbram"},"kaos":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06a6"},"characteristics":{"approach":{"_id":{"$oid":"5d473b1834653918d4ab06a8"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"exploratory"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06aa"},"id":"expertise","ref":"default","value":"high"},"formalism":{"_id":{"$oid":"5d473b1834653918d4ab06a7"},"id":"formalism","ref":"formal/semi-formal/informal","value":"formal"},"guidance":{"_id":{"$oid":"5d473b1834653918d4ab06a9"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"heuristics"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06ac"},"id":"impact","ref":"default","value":"low"},"level-of-innovation":{"_id":{"$oid":"5d473b1834653918d4ab06ab"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564949272725},"description":"KAOS for IS Security","id":"kaos","name":"KAOS","provider":"company-a","updatedAt":{"$date":1564949272725},"url":"http://example.com/KAOS"},"misuse-cases":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06b9"},"characteristics":{"approach":{"_id":{"$oid":"5d473b1834653918d4ab06bb"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"explanatory"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06bd"},"id":"expertise","ref":"default","value":"low"},"formalism":{"_id":{"$oid":"5d473b1834653918d4ab06ba"},"id":"formalism","ref":"formal/semi-formal/informal","value":"informal"},"guidance":{"_id":{"$oid":"5d473b1834653918d4ab06bc"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"guidelines"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06bf"},"id":"impact","ref":"default","value":"normal"},"level-of-innovation":{"_id":{"$oid":"5d473b1834653918d4ab06be"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564949272727},"description":"Misuse Cases for IS Security","id":"misuse-cases","name":"Misuse Cases","provider":"company-a","updatedAt":{"$date":1564949272727},"url":"http://example.com/misusecases"},"nfr-framework":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab069f"},"characteristics":{"approach":{"_id":{"$oid":"5d473b1834653918d4ab06a1"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"explanatory"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06a3"},"id":"expertise","ref":"default","value":"normal"},"formalism":{"_id":{"$oid":"5d473b1834653918d4ab06a0"},"id":"formalism","ref":"formal/semi-formal/informal","value":"semi-formal"},"guidance":{"_id":{"$oid":"5d473b1834653918d4ab06a2"},"id":"guidance","ref":"predefined taxonomy/heuristics/guidelines","value":"predefined taxonomy"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06a5"},"id":"impact","ref":"default","value":"high"},"level-of-innovation":{"_id":{"$oid":"5d473b1834653918d4ab06a4"},"id":"level-of-innovation","ref":"default","value":"high"}},"createdAt":{"$date":1564949272723},"description":"NFR Framework for IS Security","id":"nfr-framework","name":"NFR Framework","provider":"company-b","updatedAt":{"$date":1564949272723},"url":"http://example.com/NFR-framework"},"pair-programming":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06fe"},"characteristics":{"complexity":{"_id":{"$oid":"5d473b1834653918d4ab0700"},"id":"complexity","ref":"default","value":"normal"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab0702"},"id":"expertise","ref":"default","value":"low"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06ff"},"id":"impact","ref":"default","value":"high"},"resistance-and-conflict":{"_id":{"$oid":"5d473b1834653918d4ab0703"},"id":"resistance-and-conflict","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d473b1834653918d4ab0701"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564949272744},"description":"Agile software development technique in which two programmers work together at one workstation. One, the driver, writes code while the other, the observer or navigator,reviews each line of code as it is typed in. The two programmers switch roles frequently. While reviewing, the observer also considers the strategic direction of the work, coming up with ideas for improvements and likely future problems to address. This is intended to free the driver to focus all of their attention on the tactical aspects of completing the current task, using the observer as a safety net and guide. Pair programming increases the man-hours required to deliver code compared to programmers working individually. Experiments yielded diverse results, suggesting increases of between 15% and 100%. However, the resulting code has about 15% fewer defects. Along with code development time, other factors like field support costs and quality assurance also figure in to the return on investment.","id":"pair-programming","name":"Pair Programming","provider":"company-a","updatedAt":{"$date":1564949272744},"url":"http://example.com/PairProgramming"},"product-ownership":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab070a"},"characteristics":{"impact":{"_id":{"$oid":"5d473b1834653918d4ab070c"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d473b1834653918d4ab070d"},"id":"importance","ref":"default","value":"normal"},"management-commitment":{"_id":{"$oid":"5d473b1834653918d4ab070e"},"id":"management-commitment","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d473b1834653918d4ab070b"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564949272745},"description":"Own, evolve and communicate the vision, and guide the evolution of the product to achieve the vision.","id":"product-ownership","name":"Product Ownership","provider":"company-a","updatedAt":{"$date":1564949272745},"url":"http://example.com/ProductOwnership"},"secure-tropos":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab06ad"},"characteristics":{"approach":{"_id":{"$oid":"5d473b1834653918d4ab06af"},"id":"approach","ref":"systemic/exploratory/explanatory","value":"systemic"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab06b0"},"id":"expertise","ref":"default","value":"high"},"formalism":{"_id":{"$oid":"5d473b1834653918d4ab06ae"},"id":"formalism","ref":"formal/semi-formal/informal","value":"formal"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab06b2"},"id":"impact","ref":"default","value":"high"},"level-of-innovation":{"_id":{"$oid":"5d473b1834653918d4ab06b1"},"id":"level-of-innovation","ref":"default","value":"low"}},"createdAt":{"$date":1564949272726},"description":"Secure Tropos for IS Security","id":"secure-tropos","name":"Secure Tropos","provider":"company-a","updatedAt":{"$date":1564949272726},"url":"http://example.com/secure-tropos"},"specification-by-example":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab070f"},"characteristics":{"clarity-and-stability":{"_id":{"$oid":"5d473b1834653918d4ab0712"},"id":"clarity-and-stability","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab0710"},"id":"impact","ref":"default","value":"high"},"importance":{"_id":{"$oid":"5d473b1834653918d4ab0713"},"id":"importance","ref":"default","value":"high"},"management-commitment":{"_id":{"$oid":"5d473b1834653918d4ab0714"},"id":"management-commitment","ref":"default","value":"high"},"user-involvement":{"_id":{"$oid":"5d473b1834653918d4ab0711"},"id":"user-involvement","ref":"default","value":"real"}},"createdAt":{"$date":1564949272746},"description":"Specification by example (SBE) is a collaborative approach to defining requirements and business-oriented functional tests for software products based on capturing and illustrating requirements using realistic examples instead of abstract statements. It is applied in the context of agile software development methods, in particular behavior-driven development. This approach is particularly successful for managing requirements and functional tests on large-scale projects of significant domain and organisational complexity.","id":"specification-by-example","name":"Specification By Example","provider":"company-a","updatedAt":{"$date":1564949272746},"url":"http://example.com/SpecificationByExample"},"test-driven-development":{"__v":0,"_id":{"$oid":"5d473b1834653918d4ab0715"},"characteristics":{"complexity":{"_id":{"$oid":"5d473b1834653918d4ab0717"},"id":"complexity","ref":"default","value":"high"},"dependency":{"_id":{"$oid":"5d473b1834653918d4ab071a"},"id":"dependency","ref":"default","value":"high"},"expertise":{"_id":{"$oid":"5d473b1834653918d4ab0719"},"id":"expertise","ref":"default","value":"high"},"impact":{"_id":{"$oid":"5d473b1834653918d4ab0716"},"id":"impact","ref":"default","value":"high"},"tracing-project":{"_id":{"$oid":"5d473b1834653918d4ab0718"},"id":"tracing-project","ref":"default","value":"strong"}},"createdAt":{"$date":1564949272747},"description":"Test-driven development (TDD) is a software development process that relies on the repetition of a very short development cycle: requirements are turned into very specific test cases, then the software is improved to pass the new tests, only. This is opposed to software development that allows software to be added that is not proven to meet requirements. Writing the tests first: The tests should be written before the functionality that is to be tested. This has been claimed to have many benefits. It helps ensure that the application is written for testability, as the developers must consider how to test the application from the outset rather than adding it later. It also ensures that tests for every feature get written. Additionally, writing the tests first leads to a deeper and earlier understanding of the product requirements, ensures the effectiveness of the test code, and maintains a continual focus on software quality.","id":"test-driven-development","name":"Test Driven Development","provider":"company-a","updatedAt":{"$date":1564949272747},"url":"http://example.com/TestDrivenDevelopment"}}'

# %%
import json
project = json.loads(project_dict_string)
method_chunks = json.loads(method_chunks_dict_string)
characteristics = json.loads(characteristics_dict_string)

# %%
#print(json.dumps(project, indent=4))

# %%
# print(json.dumps(method_chunks, indent=4))

# %%
#print(json.dumps(characteristics, indent=4))

# %%
projectCharacteristics = project["characteristics"]
cnames = [*projectCharacteristics]
cnames
# Out:
# ['approach',
#  'expertise',
#  'formalism',
#  'guidance',
#  'impact',
#  'level-of-innovation']

# %%
import pprint
from sklearn.preprocessing import OrdinalEncoder

for cid,pc in projectCharacteristics.items():
    if(pc["rule"] == "preference_list"):
        pass
    elif(pc["rule"] == "exact"):
        pass
    else: #maximum, minimum
        if (cid in characteristics):   
            for cv in characteristics[cid]["characteristicValues"]:
                if (cv["ref"] == pc["ref"]):
                    if (pc["rule"] == "maximum"):
                        pc["value"] = list(reversed(cv["values"]))
                    else:
                        pc["value"] = cv["values"]
                    break
    values = pc["value"] + ["N/A"]
    values.reverse() # ordinal values asc order (smallest to largest)
    enc = OrdinalEncoder(categories=[values])     
    enc.fit([[v] for v in values])
    pc["encoder"] = enc

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(projectCharacteristics)
# Out:
# {   'approach': {   '_id': {'$oid': '5d461b961e66c81988a999ce'},
#                     'encoder': OrdinalEncoder(categories=[['N/A', 'explanatory', 'exploratory', 'systemic']],
#                dtype=<class 'numpy.float64'>),
#                     'id': 'approach',
#                     'ref': 'systemic/exploratory/explanatory',
#                     'rule': 'preference_list',
#                     'value': ['systemic', 'exploratory', 'explanatory']},
#     'expertise': {   '_id': {'$oid': '5d461b961e66c81988a999d0'},
#                      'encoder': OrdinalEncoder(categories=[['N/A', 'high', 'normal', 'low']],
#                dtype=<class 'numpy.float64'>),
#                      'id': 'expertise',
#                      'ref': 'default',
#                      'rule': 'minimum',
#                      'value': ['low', 'normal', 'high']},
#     'formalism': {   '_id': {'$oid': '5d461b961e66c81988a999cd'},
# ...

# %%
import pandas as pd
df = pd.DataFrame([], columns=cnames)

for mid, m in method_chunks.items():
    obj = {}
    for cid,pc in projectCharacteristics.items():
        if(cid in m["characteristics"]):
            if(pc["ref"] == m["characteristics"][cid]["ref"]):
                obj[cid] = m["characteristics"][cid]["value"]
    df = df.append(pd.Series(obj, index=df.columns, name=mid))
df.fillna("N/A",inplace=True)
df
# Out:
#                                        approach expertise    formalism  \
# acceptance-test-driven-development          N/A      high          N/A
# agile-retrospective                         N/A       N/A          N/A
# agile-teaming                               N/A      high          N/A
# behavior-driven-development                 N/A       N/A          N/A
# big-design-up-front                         N/A       N/A          N/A
# continuous-delivery                         N/A      high          N/A
# continuous-integration                      N/A      high          N/A
# daily-stand-up                              N/A       low          N/A
# gbram                                       N/A    normal     informal
# kaos                                exploratory      high       formal
# misuse-cases                        explanatory       low     informal
# nfr-framework                       explanatory    normal  semi-formal
# ...

# %%
encoded = df.copy()
for key, value in encoded.items(): 
    values = [v if v in projectCharacteristics[key]["value"] else "N/A" for v in value]
    encoded.loc[:,key]=projectCharacteristics[key]["encoder"].transform([[v] for v in values])
display(encoded)
encoded = encoded.loc[:, (encoded != 0).any(axis=0)]
display(encoded)
# Out:
#                                     approach  expertise  formalism  guidance  \
# acceptance-test-driven-development       0.0        1.0        0.0       0.0
# agile-retrospective                      0.0        0.0        0.0       0.0
# agile-teaming                            0.0        1.0        0.0       0.0
# behavior-driven-development              0.0        0.0        0.0       0.0
# big-design-up-front                      0.0        0.0        0.0       0.0
# continuous-delivery                      0.0        1.0        0.0       0.0
# continuous-integration                   0.0        1.0        0.0       0.0
# daily-stand-up                           0.0        3.0        0.0       0.0
# gbram                                    0.0        2.0        1.0       2.0
# kaos                                     2.0        1.0        3.0       2.0
# misuse-cases                             1.0        3.0        1.0       1.0
# ...

# %% [markdown]
# ### MADM

# %%
from skcriteria import Data, MAX
from skcriteria.madm import simple, closeness

optimal_senses = []
weights = []
for cid,pc in encoded.items():
    optimal_senses.append(MAX)
    weights.append(projectCharacteristics[cid].get("weight",1))

data = Data(encoded.values, optimal_senses, 
            weights=weights,
            anames=encoded.index,
            cnames=encoded.columns)
display(data)
# Out:
#             ALT./CRIT.               approach (max) W.1    expertise (max) W.1    formalism (max) W.1    guidance (max) W.1    impact (max) W.1    level-of-innovation (max) W.1
# ----------------------------------  --------------------  ---------------------  ---------------------  --------------------  ------------------  -------------------------------
# acceptance-test-driven-development           0                      1                      0                     0                    3                          0
#        agile-retrospective                   0                      0                      0                     0                    3                          0
#           agile-teaming                      0                      1                      0                     0                    0                          0
# ...

# %% [markdown]
# ### WeightedSum

# %%
model = simple.WeightedSum(mnorm="vector",wnorm="sum")
de = model.decide(data)

display(de)

print(de.e_)
print("Points:",de.e_.points)
# Out:
# WeightedSum (mnorm=vector, wnorm=sum) - Solution:
#             ALT./CRIT.               approach (max) W.1    expertise (max) W.1    formalism (max) W.1    guidance (max) W.1    impact (max) W.1    level-of-innovation (max) W.1    Rank
# ----------------------------------  --------------------  ---------------------  ---------------------  --------------------  ------------------  -------------------------------  ------
# acceptance-test-driven-development           0                      1                      0                     0                    3                          0                   8
#        agile-retrospective                   0                      0                      0                     0                    3                          0                   12
#           agile-teaming                      0                      1                      0                     0                    0                          0                   17
# ...

# %% [markdown]
# ### TOPSIS

# %%
model2 = closeness.TOPSIS(mnorm="vector",wnorm="sum")
de2 = model2.decide(data)

display(de2)
print(de2.e_)
print("Ideal:", de2.e_.ideal)
print("Anti-Ideal:", de2.e_.anti_ideal)
print("Closeness:", de2.e_.closeness)
# Out:
# TOPSIS (mnorm=vector, wnorm=sum) - Solution:
#             ALT./CRIT.               approach (max) W.1    expertise (max) W.1    formalism (max) W.1    guidance (max) W.1    impact (max) W.1    level-of-innovation (max) W.1    Rank
# ----------------------------------  --------------------  ---------------------  ---------------------  --------------------  ------------------  -------------------------------  ------
# acceptance-test-driven-development           0                      1                      0                     0                    3                          0                   8
#        agile-retrospective                   0                      0                      0                     0                    3                          0                   12
#           agile-teaming                      0                      1                      0                     0                    0                          0                   17
# ...

# %% [markdown]
# ### RESPONSE

# %%
res = {}

z = [{"methodChunk":method_chunks[de._data._anames[i]], "score":de.e_.points[i],"rank":int(de._rank[i])} for i in range(0,len(de.mtx))]
z2 = [{"methodChunk":method_chunks[de2._data._anames[i]], "score":de2.e_.closeness[i],"rank":int(de2._rank[i])} for i in range(0,len(de2.mtx))]

res["results"] = [
{
  "model": "WeightedSum",
  "values": sorted(z, key = lambda x: x["rank"])
},
{
  "model": "TOPSIS",
  "values": sorted(z2, key = lambda x: x["rank"])
}
]

for cid,pc in projectCharacteristics.items():
    pc.pop("_id",None)
    pc["encoder"] = pc["encoder"].categories[0]
project["characteristics"] = [pc for cid,pc in projectCharacteristics.items()]
project.pop("_id",None)

res["project"] = project
res
# Out:
# {'results': [{'model': 'WeightedSum',
#    'values': [{'methodChunk': {'__v': 0,
#       '_id': {'$oid': '5d473b1834653918d4ab069f'},
#       'characteristics': {'approach': {'_id': {'$oid': '5d473b1834653918d4ab06a1'},
#         'id': 'approach',
#         'ref': 'systemic/exploratory/explanatory',
#         'value': 'explanatory'},
#        'expertise': {'_id': {'$oid': '5d473b1834653918d4ab06a3'},
#         'id': 'expertise',
#         'ref': 'default',
#         'value': 'normal'},
#        'formalism': {'_id': {'$oid': '5d473b1834653918d4ab06a0'},
#         'id': 'formalism',
#         'ref': 'formal/semi-formal/informal',
#         'value': 'semi-formal'},
#        'guidance': {'_id': {'$oid': '5d473b1834653918d4ab06a2'},
#         'id': 'guidance',
#         'ref': 'predefined taxonomy/heuristics/guidelines',
#         'value': 'predefined taxonomy'},
#        'impact': {'_id': {'$oid': '5d473b1834653918d4ab06a5'},
#         'id': 'impact',
#         'ref': 'default',
# ...
